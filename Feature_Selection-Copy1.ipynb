# %% [markdown]
# <H1>Filter Method</H1>

# %% [markdown]
# <H2>Variance Threshold</H2>

# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv1D, Flatten, Dense
from sklearn.metrics import accuracy_score

# Load dataset
file_path = "Downloads/preprocessed_covid500.csv"  # Update with the correct path to your dataset
df = pd.read_csv(file_path)

# Drop the 'source' feature if it exists
#df = df.drop(columns=['data_source'], errors='ignore')

# Separate features and target variable
X = df.drop(columns=['COVID-19'])
y = df['COVID-19']

# Variance Threshold Function
def variance_threshold(X, threshold=0.1):
    selector = VarianceThreshold(threshold)
    selector.fit(X)
    return X.columns[selector.get_support()]

# Apply Variance Threshold
selected_features = variance_threshold(X)

# Print the features selected by Variance Threshold
print("Features Selected by Variance Threshold:")
for feature in selected_features:
    print(feature)

# Filter the dataset to keep only the selected features
X_selected = X[selected_features]

# Prepare Data for 1D CNN
X_selected = X_selected.values.reshape(X_selected.shape[0], X_selected.shape[1], 1)  # Reshape for CNN
y = y.values  # Convert target variable to numpy array

# Split the Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# Build and Train the 1D CNN Model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_selected.shape[1], 1)))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))  # Adjust output layer based on your problem

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=32)  # Adjust epochs and batch size as needed

# Evaluate the Model
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)  # Convert probabilities to binary class predictions

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_classes)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Features Selected by Variance Threshold:
# Running Nose
# Asthma
# Chronic Lung Disease
# Headache
# Heart Disease
# Diabetes
# Hyper Tension
# Abroad travel
# Contact with COVID Patient
# Attended Large Gathering
# Visited Public Exposed Places
# Family working in Public Exposed Places
# Epoch 1/10
# C:\Users\aurok\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8751 - loss: 0.3497
# Epoch 2/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9366 - loss: 0.1878
# Epoch 3/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9407 - loss: 0.1798
# Epoch 4/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9459 - loss: 0.1736
# Epoch 5/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9440 - loss: 0.1748
# Epoch 6/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9472 - loss: 0.1713
# Epoch 7/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9463 - loss: 0.1703
# Epoch 8/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9475 - loss: 0.1704
# Epoch 9/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9451 - loss: 0.1724
# Epoch 10/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9443 - loss: 0.1703
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step
# Accuracy: 0.9396

# %% [markdown]
# <H2>Chi Squared Test</H2>

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv1D, Flatten, Dense
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score

# Load dataset
file_path = "Downloads/preprocessed_covid500.csv"  # Update with the correct path to your dataset
#df = pd.read_csv(file_path)

# Drop the 'source' feature if it exists
df = df.drop(columns=['source'], errors='ignore')

# Separate features and target variable
X = df.drop(columns=['COVID-19'])
y = df['COVID-19']

# Chi-squared Test Function
def chi_squared(X, y, k=10):  # Set k to the number of features you want to select
    chi2_selector = SelectKBest(chi2, k=k)
    chi2_selector.fit(X, y)
    return X.columns[chi2_selector.get_support()]

# Apply Chi-squared Test
selected_features = chi_squared(X, y, k=10)  # Change k to the desired number of features

# Print the features selected by Chi-squared Test
print("Features Selected by Chi-squared Test:")
for feature in selected_features:
    print(feature)

# Filter the dataset to keep only the selected features
X_selected = X[selected_features]

# Prepare Data for 1D CNN
X_selected = X_selected.values.reshape(X_selected.shape[0], X_selected.shape[1], 1)  # Reshape for CNN
y = y.values  # Convert target variable to numpy array

# Split the Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# Build and Train the 1D CNN Model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_selected.shape[1], 1)))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))  # Adjust output layer based on your problem

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model with early stopping
model.fit(X_train, y_train, epochs=10000, batch_size=32, validation_split=0.2, callbacks=[early_stopping])  # Adjust epochs and batch size as needed

# Evaluate the Model
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)  # Convert probabilities to binary class predictions

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_classes)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Features Selected by Chi-squared Test:
# Asthma
# Chronic Lung Disease
# Headache
# Heart Disease
# Diabetes
# Abroad travel
# Contact with COVID Patient
# Attended Large Gathering
# Visited Public Exposed Places
# Family working in Public Exposed Places
# Epoch 1/10000
# C:\Users\aurok\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8670 - loss: 0.3655 - val_accuracy: 0.9246 - val_loss: 0.2056
# Epoch 2/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9340 - loss: 0.1900 - val_accuracy: 0.9226 - val_loss: 0.1991
# Epoch 3/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9352 - loss: 0.1921 - val_accuracy: 0.9399 - val_loss: 0.1930
# Epoch 4/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9417 - loss: 0.1851 - val_accuracy: 0.9338 - val_loss: 0.1936
# Epoch 5/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9401 - loss: 0.1900 - val_accuracy: 0.9398 - val_loss: 0.1917
# Epoch 6/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9429 - loss: 0.1831 - val_accuracy: 0.9414 - val_loss: 0.1896
# Epoch 7/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9416 - loss: 0.1899 - val_accuracy: 0.9383 - val_loss: 0.1884
# Epoch 8/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9409 - loss: 0.1884 - val_accuracy: 0.9426 - val_loss: 0.1887
# Epoch 9/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9422 - loss: 0.1849 - val_accuracy: 0.9427 - val_loss: 0.1883
# Epoch 10/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9412 - loss: 0.1879 - val_accuracy: 0.9422 - val_loss: 0.1874
# Epoch 11/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9459 - loss: 0.1841 - val_accuracy: 0.9384 - val_loss: 0.1882
# Epoch 12/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9412 - loss: 0.1853 - val_accuracy: 0.9430 - val_loss: 0.1880
# Epoch 13/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9446 - loss: 0.1781 - val_accuracy: 0.9430 - val_loss: 0.1876
# Epoch 14/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9437 - loss: 0.1821 - val_accuracy: 0.9419 - val_loss: 0.1868
# Epoch 15/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9430 - loss: 0.1839 - val_accuracy: 0.9425 - val_loss: 0.1857
# Epoch 16/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1811 - val_accuracy: 0.9402 - val_loss: 0.1856
# Epoch 17/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9422 - loss: 0.1842 - val_accuracy: 0.9418 - val_loss: 0.1860
# Epoch 18/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9437 - loss: 0.1801 - val_accuracy: 0.9437 - val_loss: 0.1860
# Epoch 19/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9424 - loss: 0.1830 - val_accuracy: 0.9411 - val_loss: 0.1863
# Epoch 20/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1826 - val_accuracy: 0.9408 - val_loss: 0.1852
# Epoch 21/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9454 - loss: 0.1765 - val_accuracy: 0.9433 - val_loss: 0.1854
# Epoch 22/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9406 - loss: 0.1878 - val_accuracy: 0.9422 - val_loss: 0.1850
# Epoch 23/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9465 - loss: 0.1749 - val_accuracy: 0.9438 - val_loss: 0.1853
# Epoch 24/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9465 - loss: 0.1783 - val_accuracy: 0.9435 - val_loss: 0.1848
# Epoch 25/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9455 - loss: 0.1794 - val_accuracy: 0.9422 - val_loss: 0.1855
# Epoch 26/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9446 - loss: 0.1804 - val_accuracy: 0.9418 - val_loss: 0.1855
# Epoch 27/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9449 - loss: 0.1781 - val_accuracy: 0.9431 - val_loss: 0.1855
# Epoch 28/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9454 - loss: 0.1773 - val_accuracy: 0.9426 - val_loss: 0.1851
# Epoch 29/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9443 - loss: 0.1806 - val_accuracy: 0.9435 - val_loss: 0.1846
# Epoch 30/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9454 - loss: 0.1810 - val_accuracy: 0.9438 - val_loss: 0.1845
# Epoch 31/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9435 - loss: 0.1817 - val_accuracy: 0.9419 - val_loss: 0.1860
# Epoch 32/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9420 - loss: 0.1864 - val_accuracy: 0.9427 - val_loss: 0.1845
# Epoch 33/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9436 - loss: 0.1800 - val_accuracy: 0.9400 - val_loss: 0.1862
# Epoch 34/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9433 - loss: 0.1832 - val_accuracy: 0.9439 - val_loss: 0.1841
# Epoch 35/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9439 - loss: 0.1830 - val_accuracy: 0.9414 - val_loss: 0.1841
# Epoch 36/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9431 - loss: 0.1824 - val_accuracy: 0.9433 - val_loss: 0.1841
# Epoch 37/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9444 - loss: 0.1789 - val_accuracy: 0.9422 - val_loss: 0.1839
# Epoch 38/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9444 - loss: 0.1789 - val_accuracy: 0.9425 - val_loss: 0.1850
# Epoch 39/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9445 - loss: 0.1807 - val_accuracy: 0.9408 - val_loss: 0.1864
# Epoch 40/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9449 - loss: 0.1808 - val_accuracy: 0.9431 - val_loss: 0.1843
# Epoch 41/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9436 - loss: 0.1817 - val_accuracy: 0.9427 - val_loss: 0.1849
# Epoch 42/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9433 - loss: 0.1820 - val_accuracy: 0.9419 - val_loss: 0.1855
# Epoch 43/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9449 - loss: 0.1790 - val_accuracy: 0.9395 - val_loss: 0.1860
# Epoch 44/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1810 - val_accuracy: 0.9433 - val_loss: 0.1853
# Epoch 45/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1809 - val_accuracy: 0.9439 - val_loss: 0.1841
# Epoch 46/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9468 - loss: 0.1754 - val_accuracy: 0.9427 - val_loss: 0.1834
# Epoch 47/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9448 - loss: 0.1808 - val_accuracy: 0.9434 - val_loss: 0.1844
# Epoch 48/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9457 - loss: 0.1759 - val_accuracy: 0.9418 - val_loss: 0.1840
# Epoch 49/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9433 - loss: 0.1837 - val_accuracy: 0.9421 - val_loss: 0.1849
# Epoch 50/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1819 - val_accuracy: 0.9430 - val_loss: 0.1852
# Epoch 51/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1852 - val_accuracy: 0.9438 - val_loss: 0.1852
# Epoch 52/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9425 - loss: 0.1840 - val_accuracy: 0.9427 - val_loss: 0.1834
# Epoch 53/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9443 - loss: 0.1814 - val_accuracy: 0.9433 - val_loss: 0.1830
# Epoch 54/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9455 - loss: 0.1786 - val_accuracy: 0.9441 - val_loss: 0.1836
# Epoch 55/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1787 - val_accuracy: 0.9446 - val_loss: 0.1837
# Epoch 56/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9428 - loss: 0.1860 - val_accuracy: 0.9431 - val_loss: 0.1839
# Epoch 57/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9456 - loss: 0.1776 - val_accuracy: 0.9422 - val_loss: 0.1850
# Epoch 58/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9455 - loss: 0.1808 - val_accuracy: 0.9437 - val_loss: 0.1834
# Epoch 59/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9453 - loss: 0.1777 - val_accuracy: 0.9442 - val_loss: 0.1841
# Epoch 60/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9447 - loss: 0.1795 - val_accuracy: 0.9437 - val_loss: 0.1835
# Epoch 61/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1821 - val_accuracy: 0.9421 - val_loss: 0.1840
# Epoch 62/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9447 - loss: 0.1810 - val_accuracy: 0.9421 - val_loss: 0.1831
# Epoch 63/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9414 - loss: 0.1877 - val_accuracy: 0.9444 - val_loss: 0.1862
# Epoch 64/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9460 - loss: 0.1784 - val_accuracy: 0.9415 - val_loss: 0.1879
# Epoch 65/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9454 - loss: 0.1779 - val_accuracy: 0.9439 - val_loss: 0.1830
# Epoch 66/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9444 - loss: 0.1803 - val_accuracy: 0.9429 - val_loss: 0.1831
# Epoch 67/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9425 - loss: 0.1830 - val_accuracy: 0.9433 - val_loss: 0.1832
# Epoch 68/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9436 - loss: 0.1842 - val_accuracy: 0.9427 - val_loss: 0.1833
# Epoch 69/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9446 - loss: 0.1828 - val_accuracy: 0.9427 - val_loss: 0.1863
# Epoch 70/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9434 - loss: 0.1823 - val_accuracy: 0.9412 - val_loss: 0.1840
# Epoch 71/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9431 - loss: 0.1807 - val_accuracy: 0.9437 - val_loss: 0.1853
# Epoch 72/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9443 - loss: 0.1809 - val_accuracy: 0.9403 - val_loss: 0.1829
# Epoch 73/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9447 - loss: 0.1792 - val_accuracy: 0.9437 - val_loss: 0.1827
# Epoch 74/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9438 - loss: 0.1828 - val_accuracy: 0.9422 - val_loss: 0.1830
# Epoch 75/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9454 - loss: 0.1788 - val_accuracy: 0.9421 - val_loss: 0.1842
# Epoch 76/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9464 - loss: 0.1778 - val_accuracy: 0.9446 - val_loss: 0.1827
# Epoch 77/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9433 - loss: 0.1852 - val_accuracy: 0.9423 - val_loss: 0.1881
# Epoch 78/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9443 - loss: 0.1817 - val_accuracy: 0.9431 - val_loss: 0.1829
# Epoch 79/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9445 - loss: 0.1793 - val_accuracy: 0.9438 - val_loss: 0.1831
# Epoch 80/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9450 - loss: 0.1790 - val_accuracy: 0.9450 - val_loss: 0.1837
# Epoch 81/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9451 - loss: 0.1782 - val_accuracy: 0.9439 - val_loss: 0.1829
# Epoch 82/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9458 - loss: 0.1774 - val_accuracy: 0.9426 - val_loss: 0.1868
# Epoch 83/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9440 - loss: 0.1794 - val_accuracy: 0.9441 - val_loss: 0.1831
# Epoch 84/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9465 - loss: 0.1752 - val_accuracy: 0.9438 - val_loss: 0.1838
# Epoch 85/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9455 - loss: 0.1748 - val_accuracy: 0.9444 - val_loss: 0.1827
# Epoch 86/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9453 - loss: 0.1787 - val_accuracy: 0.9433 - val_loss: 0.1826
# Epoch 87/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9454 - loss: 0.1781 - val_accuracy: 0.9442 - val_loss: 0.1843
# Epoch 88/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9397 - loss: 0.1882 - val_accuracy: 0.9422 - val_loss: 0.1837
# Epoch 89/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9443 - loss: 0.1834 - val_accuracy: 0.9439 - val_loss: 0.1838
# Epoch 90/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9426 - loss: 0.1819 - val_accuracy: 0.9438 - val_loss: 0.1833
# Epoch 91/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9438 - loss: 0.1833 - val_accuracy: 0.9433 - val_loss: 0.1825
# Epoch 92/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9467 - loss: 0.1767 - val_accuracy: 0.9442 - val_loss: 0.1833
# Epoch 93/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9476 - loss: 0.1744 - val_accuracy: 0.9426 - val_loss: 0.1829
# Epoch 94/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9444 - loss: 0.1815 - val_accuracy: 0.9438 - val_loss: 0.1860
# Epoch 95/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9410 - loss: 0.1865 - val_accuracy: 0.9437 - val_loss: 0.1861
# Epoch 96/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1783 - val_accuracy: 0.9437 - val_loss: 0.1838
# Epoch 97/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9425 - loss: 0.1848 - val_accuracy: 0.9445 - val_loss: 0.1831
# Epoch 98/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9462 - loss: 0.1775 - val_accuracy: 0.9441 - val_loss: 0.1833
# Epoch 99/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9435 - loss: 0.1816 - val_accuracy: 0.9412 - val_loss: 0.1840
# Epoch 100/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9438 - loss: 0.1811 - val_accuracy: 0.9442 - val_loss: 0.1825
# Epoch 101/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9438 - loss: 0.1796 - val_accuracy: 0.9444 - val_loss: 0.1824
# Epoch 102/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1831 - val_accuracy: 0.9433 - val_loss: 0.1825
# Epoch 103/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9444 - loss: 0.1822 - val_accuracy: 0.9431 - val_loss: 0.1826
# Epoch 104/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9462 - loss: 0.1750 - val_accuracy: 0.9430 - val_loss: 0.1823
# Epoch 105/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9448 - loss: 0.1826 - val_accuracy: 0.9445 - val_loss: 0.1834
# Epoch 106/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9451 - loss: 0.1806 - val_accuracy: 0.9422 - val_loss: 0.1846
# Epoch 107/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9440 - loss: 0.1803 - val_accuracy: 0.9437 - val_loss: 0.1831
# Epoch 108/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9459 - loss: 0.1784 - val_accuracy: 0.9441 - val_loss: 0.1829
# Epoch 109/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9435 - loss: 0.1806 - val_accuracy: 0.9415 - val_loss: 0.1836
# Epoch 110/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1814 - val_accuracy: 0.9442 - val_loss: 0.1833
# Epoch 111/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9454 - loss: 0.1791 - val_accuracy: 0.9446 - val_loss: 0.1822
# Epoch 112/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9464 - loss: 0.1791 - val_accuracy: 0.9454 - val_loss: 0.1845
# Epoch 113/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9458 - loss: 0.1775 - val_accuracy: 0.9430 - val_loss: 0.1845
# Epoch 114/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9431 - loss: 0.1818 - val_accuracy: 0.9448 - val_loss: 0.1830
# Epoch 115/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9456 - loss: 0.1798 - val_accuracy: 0.9442 - val_loss: 0.1838
# Epoch 116/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1796 - val_accuracy: 0.9439 - val_loss: 0.1829
# Epoch 117/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9444 - loss: 0.1806 - val_accuracy: 0.9448 - val_loss: 0.1840
# Epoch 118/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1800 - val_accuracy: 0.9445 - val_loss: 0.1828
# Epoch 119/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9441 - loss: 0.1838 - val_accuracy: 0.9448 - val_loss: 0.1825
# Epoch 120/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9474 - loss: 0.1745 - val_accuracy: 0.9437 - val_loss: 0.1844
# Epoch 121/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9444 - loss: 0.1780 - val_accuracy: 0.9410 - val_loss: 0.1878
# Epoch 122/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9434 - loss: 0.1830 - val_accuracy: 0.9444 - val_loss: 0.1823
# Epoch 123/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9457 - loss: 0.1777 - val_accuracy: 0.9426 - val_loss: 0.1826
# Epoch 124/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9415 - loss: 0.1883 - val_accuracy: 0.9442 - val_loss: 0.1822
# Epoch 125/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9427 - loss: 0.1818 - val_accuracy: 0.9444 - val_loss: 0.1822
# Epoch 126/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9440 - loss: 0.1818 - val_accuracy: 0.9434 - val_loss: 0.1832
# Epoch 127/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9423 - loss: 0.1875 - val_accuracy: 0.9448 - val_loss: 0.1823
# Epoch 128/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9419 - loss: 0.1843 - val_accuracy: 0.9435 - val_loss: 0.1824
# Epoch 129/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9439 - loss: 0.1828 - val_accuracy: 0.9437 - val_loss: 0.1820
# Epoch 130/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9464 - loss: 0.1762 - val_accuracy: 0.9448 - val_loss: 0.1822
# Epoch 131/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9471 - loss: 0.1790 - val_accuracy: 0.9444 - val_loss: 0.1840
# Epoch 132/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9449 - loss: 0.1790 - val_accuracy: 0.9433 - val_loss: 0.1834
# Epoch 133/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9469 - loss: 0.1760 - val_accuracy: 0.9448 - val_loss: 0.1825
# Epoch 134/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9450 - loss: 0.1801 - val_accuracy: 0.9426 - val_loss: 0.1832
# Epoch 135/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9472 - loss: 0.1747 - val_accuracy: 0.9442 - val_loss: 0.1824
# Epoch 136/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9456 - loss: 0.1789 - val_accuracy: 0.9438 - val_loss: 0.1826
# Epoch 137/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9461 - loss: 0.1753 - val_accuracy: 0.9449 - val_loss: 0.1825
# Epoch 138/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9444 - loss: 0.1805 - val_accuracy: 0.9438 - val_loss: 0.1821
# Epoch 139/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1829 - val_accuracy: 0.9421 - val_loss: 0.1859
# Epoch 140/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9463 - loss: 0.1770 - val_accuracy: 0.9435 - val_loss: 0.1833
# Epoch 141/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9447 - loss: 0.1803 - val_accuracy: 0.9445 - val_loss: 0.1822
# Epoch 142/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1824 - val_accuracy: 0.9444 - val_loss: 0.1822
# Epoch 143/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9462 - loss: 0.1767 - val_accuracy: 0.9444 - val_loss: 0.1822
# Epoch 144/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9451 - loss: 0.1797 - val_accuracy: 0.9434 - val_loss: 0.1829
# Epoch 145/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9459 - loss: 0.1771 - val_accuracy: 0.9449 - val_loss: 0.1821
# Epoch 146/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9446 - loss: 0.1795 - val_accuracy: 0.9421 - val_loss: 0.1823
# Epoch 147/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9457 - loss: 0.1769 - val_accuracy: 0.9439 - val_loss: 0.1826
# Epoch 148/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9446 - loss: 0.1793 - val_accuracy: 0.9431 - val_loss: 0.1821
# Epoch 149/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1825 - val_accuracy: 0.9456 - val_loss: 0.1852
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# Accuracy: 0.9393

# %%
import pandas as pd
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv1D, Flatten, Dense
from sklearn.metrics import accuracy_score

# Load dataset
file_path = "Downloads/preprocessed_covid500.csv"  # Update with the correct path to your dataset
df = pd.read_csv(file_path)

# Drop the 'source' feature if it exists
#df = df.drop(columns=['source'], errors='ignore')

# Separate features and target variable
X = df.drop(columns=['COVID-19'])
y = df['COVID-19']

# Mutual Information Function
def mutual_information(X, y, num_features=10):  # Set num_features to the number of features you want to select
    mi = mutual_info_classif(X, y, discrete_features='auto')
    mi_series = pd.Series(mi, index=X.columns)
    return mi_series.nlargest(num_features).index  # Select the top num_features

# Apply Mutual Information
selected_features = mutual_information(X, y, num_features=10)  # Change num_features to the desired number of features

# Print the features selected by Mutual Information
print("Features Selected by Mutual Information:")
for feature in selected_features:
    print(feature)

# Filter the dataset to keep only the selected features
X_selected = X[selected_features]

# Prepare Data for 1D CNN
X_selected = X_selected.values.reshape(X_selected.shape[0], X_selected.shape[1], 1)  # Reshape for CNN
y = y.values  # Convert target variable to numpy array

# Split the Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# Build and Train the 1D CNN Model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_selected.shape[1], 1)))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))  # Adjust output layer based on your problem

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=32)  # Adjust epochs and batch size as needed
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model with early stopping
model.fit(X_train, y_train, epochs=10000, batch_size=32, validation_split=0.2, callbacks=[early_stopping])  # Adjust epochs and batch size as needed

# Evaluate the Model
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)  # Convert probabilities to binary class predictions

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_classes)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Features Selected by Mutual Information:
# Abroad travel
# Attended Large Gathering
# Diabetes
# Family working in Public Exposed Places
# Visited Public Exposed Places
# Asthma
# Headache
# Heart Disease
# Chronic Lung Disease
# Contact with COVID Patient
# Epoch 1/10
# C:\Users\aurok\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8347 - loss: 0.3884
# Epoch 2/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9350 - loss: 0.2040
# Epoch 3/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9410 - loss: 0.1933
# Epoch 4/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9436 - loss: 0.1876
# Epoch 5/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9410 - loss: 0.1924
# Epoch 6/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9452 - loss: 0.1826
# Epoch 7/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9447 - loss: 0.1856
# Epoch 8/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9436 - loss: 0.1856
# Epoch 9/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9468 - loss: 0.1810
# Epoch 10/10
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9453 - loss: 0.1833
# Epoch 1/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9472 - loss: 0.1808 - val_accuracy: 0.9400 - val_loss: 0.1900
# Epoch 2/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9454 - loss: 0.1828 - val_accuracy: 0.9410 - val_loss: 0.1901
# Epoch 3/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9457 - loss: 0.1840 - val_accuracy: 0.9399 - val_loss: 0.1936
# Epoch 4/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9423 - loss: 0.1911 - val_accuracy: 0.9412 - val_loss: 0.1896
# Epoch 5/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9457 - loss: 0.1797 - val_accuracy: 0.9395 - val_loss: 0.1900
# Epoch 6/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9468 - loss: 0.1817 - val_accuracy: 0.9408 - val_loss: 0.1896
# Epoch 7/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9430 - loss: 0.1886 - val_accuracy: 0.9427 - val_loss: 0.1890
# Epoch 8/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9462 - loss: 0.1832 - val_accuracy: 0.9425 - val_loss: 0.1908
# Epoch 9/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9464 - loss: 0.1802 - val_accuracy: 0.9408 - val_loss: 0.1892
# Epoch 10/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9449 - loss: 0.1861 - val_accuracy: 0.9411 - val_loss: 0.1893
# Epoch 11/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9470 - loss: 0.1819 - val_accuracy: 0.9427 - val_loss: 0.1883
# Epoch 12/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9461 - loss: 0.1835 - val_accuracy: 0.9421 - val_loss: 0.1887
# Epoch 13/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9476 - loss: 0.1768 - val_accuracy: 0.9426 - val_loss: 0.1881
# Epoch 14/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9449 - loss: 0.1854 - val_accuracy: 0.9414 - val_loss: 0.1891
# Epoch 15/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1864 - val_accuracy: 0.9423 - val_loss: 0.1886
# Epoch 16/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9460 - loss: 0.1834 - val_accuracy: 0.9419 - val_loss: 0.1898
# Epoch 17/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9463 - loss: 0.1846 - val_accuracy: 0.9426 - val_loss: 0.1877
# Epoch 18/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9456 - loss: 0.1854 - val_accuracy: 0.9423 - val_loss: 0.1894
# Epoch 19/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9478 - loss: 0.1799 - val_accuracy: 0.9423 - val_loss: 0.1881
# Epoch 20/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9463 - loss: 0.1861 - val_accuracy: 0.9425 - val_loss: 0.1897
# Epoch 21/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9457 - loss: 0.1829 - val_accuracy: 0.9425 - val_loss: 0.1895
# Epoch 22/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9474 - loss: 0.1810 - val_accuracy: 0.9421 - val_loss: 0.1875
# Epoch 23/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9472 - loss: 0.1816 - val_accuracy: 0.9419 - val_loss: 0.1891
# Epoch 24/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9473 - loss: 0.1819 - val_accuracy: 0.9410 - val_loss: 0.1885
# Epoch 25/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9468 - loss: 0.1833 - val_accuracy: 0.9438 - val_loss: 0.1893
# Epoch 26/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9474 - loss: 0.1846 - val_accuracy: 0.9423 - val_loss: 0.1874
# Epoch 27/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9447 - loss: 0.1863 - val_accuracy: 0.9429 - val_loss: 0.1878
# Epoch 28/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9476 - loss: 0.1809 - val_accuracy: 0.9430 - val_loss: 0.1875
# Epoch 29/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9479 - loss: 0.1790 - val_accuracy: 0.9426 - val_loss: 0.1875
# Epoch 30/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9462 - loss: 0.1827 - val_accuracy: 0.9433 - val_loss: 0.1871
# Epoch 31/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9490 - loss: 0.1761 - val_accuracy: 0.9429 - val_loss: 0.1867
# Epoch 32/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9483 - loss: 0.1784 - val_accuracy: 0.9433 - val_loss: 0.1880
# Epoch 33/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9455 - loss: 0.1846 - val_accuracy: 0.9427 - val_loss: 0.1871
# Epoch 34/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9462 - loss: 0.1837 - val_accuracy: 0.9431 - val_loss: 0.1883
# Epoch 35/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9440 - loss: 0.1880 - val_accuracy: 0.9442 - val_loss: 0.1890
# Epoch 36/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9459 - loss: 0.1833 - val_accuracy: 0.9415 - val_loss: 0.1902
# Epoch 37/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9496 - loss: 0.1752 - val_accuracy: 0.9439 - val_loss: 0.1874
# Epoch 38/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9487 - loss: 0.1792 - val_accuracy: 0.9423 - val_loss: 0.1878
# Epoch 39/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9476 - loss: 0.1798 - val_accuracy: 0.9419 - val_loss: 0.1883
# Epoch 40/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9472 - loss: 0.1801 - val_accuracy: 0.9422 - val_loss: 0.1869
# Epoch 41/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9476 - loss: 0.1794 - val_accuracy: 0.9425 - val_loss: 0.1872
# Epoch 42/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9480 - loss: 0.1788 - val_accuracy: 0.9435 - val_loss: 0.1878
# Epoch 43/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9476 - loss: 0.1820 - val_accuracy: 0.9433 - val_loss: 0.1873
# Epoch 44/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9469 - loss: 0.1816 - val_accuracy: 0.9439 - val_loss: 0.1883
# Epoch 45/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9453 - loss: 0.1896 - val_accuracy: 0.9429 - val_loss: 0.1875
# Epoch 46/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9492 - loss: 0.1752 - val_accuracy: 0.9434 - val_loss: 0.1876
# Epoch 47/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9468 - loss: 0.1846 - val_accuracy: 0.9431 - val_loss: 0.1875
# Epoch 48/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9486 - loss: 0.1806 - val_accuracy: 0.9434 - val_loss: 0.1869
# Epoch 49/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9451 - loss: 0.1870 - val_accuracy: 0.9427 - val_loss: 0.1874
# Epoch 50/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9483 - loss: 0.1774 - val_accuracy: 0.9438 - val_loss: 0.1884
# Epoch 51/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9475 - loss: 0.1800 - val_accuracy: 0.9429 - val_loss: 0.1880
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step
# Accuracy: 0.9405

# %% [markdown]
# <H1>Mutual Information</H1>

# %%
import pandas as pd
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv1D, Flatten, Dense
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score

# Load dataset
file_path = "Downloads/preprocessed_covid500.csv"  # Update with the correct path to your dataset
df = pd.read_csv(file_path)

# Drop the 'source' feature if it exists
# df = df.drop(columns=['source'], errors='ignore')

# Separate features and target variable
X = df.drop(columns=['COVID-19'])
y = df['COVID-19']

# Mutual Information Function
def mutual_information(X, y, num_features=10):
    """
    Calculate mutual information between features and target variable,
    and return the top num_features based on mutual information scores.
    
    Parameters:
    - X: DataFrame of features
    - y: Series of target variable
    - num_features: Number of top features to select based on mutual information
    
    Returns:
    - List of selected feature names
    """
    mi = mutual_info_classif(X, y, discrete_features='auto')
    mi_series = pd.Series(mi, index=X.columns)
    return mi_series.nlargest(num_features).index.tolist()  # Return as a list

# Apply Mutual Information
num_features_to_select = 10  # Change this to the desired number of features
selected_features = mutual_information(X, y, num_features=num_features_to_select)

# Print the features selected by Mutual Information
print("Features Selected by Mutual Information:")
for feature in selected_features:
    print(feature)

# Filter the dataset to keep only the selected features
X_selected = X[selected_features]

# Prepare Data for 1D CNN
X_selected = X_selected.values.reshape(X_selected.shape[0], X_selected.shape[1], 1)  # Reshape for CNN
y = y.values  # Convert target variable to numpy array

# Split the Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# Build and Train the 1D CNN Model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_selected.shape[1], 1)))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))  # Adjust output layer based on your problem

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model with early stopping
model.fit(X_train, y_train, epochs=10000, batch_size=32, validation_split=0.2, callbacks=[early_stopping])  # Adjust epochs and batch size as needed

# Evaluate the Model
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)  # Convert probabilities to binary class predictions

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_classes)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Features Selected by Mutual Information:
# Abroad travel
# Attended Large Gathering
# Diabetes
# Family working in Public Exposed Places
# Visited Public Exposed Places
# Asthma
# Headache
# Heart Disease
# Chronic Lung Disease
# Breathing Problem
# Epoch 1/10000
# C:\Users\aurok\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8030 - loss: 0.4288 - val_accuracy: 0.9142 - val_loss: 0.2374
# Epoch 2/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9109 - loss: 0.2281 - val_accuracy: 0.9236 - val_loss: 0.2214
# Epoch 3/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9282 - loss: 0.2147 - val_accuracy: 0.9267 - val_loss: 0.2177
# Epoch 4/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9317 - loss: 0.2066 - val_accuracy: 0.9271 - val_loss: 0.2161
# Epoch 5/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9305 - loss: 0.2072 - val_accuracy: 0.9179 - val_loss: 0.2159
# Epoch 6/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9325 - loss: 0.2088 - val_accuracy: 0.9367 - val_loss: 0.2132
# Epoch 7/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9344 - loss: 0.2084 - val_accuracy: 0.9221 - val_loss: 0.2138
# Epoch 8/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9353 - loss: 0.2082 - val_accuracy: 0.9348 - val_loss: 0.2131
# Epoch 9/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9359 - loss: 0.2044 - val_accuracy: 0.9365 - val_loss: 0.2106
# Epoch 10/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9384 - loss: 0.2009 - val_accuracy: 0.9340 - val_loss: 0.2100
# Epoch 11/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9379 - loss: 0.2038 - val_accuracy: 0.9354 - val_loss: 0.2101
# Epoch 12/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9391 - loss: 0.1990 - val_accuracy: 0.9345 - val_loss: 0.2094
# Epoch 13/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9336 - loss: 0.2103 - val_accuracy: 0.9350 - val_loss: 0.2087
# Epoch 14/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9367 - loss: 0.2042 - val_accuracy: 0.9335 - val_loss: 0.2084
# Epoch 15/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9354 - loss: 0.2056 - val_accuracy: 0.9345 - val_loss: 0.2088
# Epoch 16/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9348 - loss: 0.2101 - val_accuracy: 0.9330 - val_loss: 0.2083
# Epoch 17/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9362 - loss: 0.2029 - val_accuracy: 0.9364 - val_loss: 0.2068
# Epoch 18/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9363 - loss: 0.2028 - val_accuracy: 0.9321 - val_loss: 0.2074
# Epoch 19/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9367 - loss: 0.2027 - val_accuracy: 0.9360 - val_loss: 0.2072
# Epoch 20/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9346 - loss: 0.2114 - val_accuracy: 0.9342 - val_loss: 0.2087
# Epoch 21/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9381 - loss: 0.2009 - val_accuracy: 0.9348 - val_loss: 0.2095
# Epoch 22/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9382 - loss: 0.2010 - val_accuracy: 0.9350 - val_loss: 0.2064
# Epoch 23/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9358 - loss: 0.2026 - val_accuracy: 0.9357 - val_loss: 0.2075
# Epoch 24/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9360 - loss: 0.2015 - val_accuracy: 0.9350 - val_loss: 0.2084
# Epoch 25/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9364 - loss: 0.2025 - val_accuracy: 0.9360 - val_loss: 0.2063
# Epoch 26/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9352 - loss: 0.2072 - val_accuracy: 0.9348 - val_loss: 0.2073
# Epoch 27/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9387 - loss: 0.1988 - val_accuracy: 0.9356 - val_loss: 0.2062
# Epoch 28/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9373 - loss: 0.1997 - val_accuracy: 0.9352 - val_loss: 0.2064
# Epoch 29/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9346 - loss: 0.2043 - val_accuracy: 0.9358 - val_loss: 0.2063
# Epoch 30/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9334 - loss: 0.2086 - val_accuracy: 0.9372 - val_loss: 0.2055
# Epoch 31/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9386 - loss: 0.2023 - val_accuracy: 0.9358 - val_loss: 0.2074
# Epoch 32/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9366 - loss: 0.2022 - val_accuracy: 0.9350 - val_loss: 0.2073
# Epoch 33/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9368 - loss: 0.2017 - val_accuracy: 0.9321 - val_loss: 0.2063
# Epoch 34/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9383 - loss: 0.2012 - val_accuracy: 0.9346 - val_loss: 0.2072
# Epoch 35/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9385 - loss: 0.1989 - val_accuracy: 0.9373 - val_loss: 0.2056
# Epoch 36/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9373 - loss: 0.2029 - val_accuracy: 0.9363 - val_loss: 0.2056
# Epoch 37/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9361 - loss: 0.2052 - val_accuracy: 0.9367 - val_loss: 0.2061
# Epoch 38/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9366 - loss: 0.2037 - val_accuracy: 0.9383 - val_loss: 0.2058
# Epoch 39/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9383 - loss: 0.1994 - val_accuracy: 0.9353 - val_loss: 0.2059
# Epoch 40/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9367 - loss: 0.2013 - val_accuracy: 0.9376 - val_loss: 0.2049
# Epoch 41/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9390 - loss: 0.2000 - val_accuracy: 0.9371 - val_loss: 0.2061
# Epoch 42/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9375 - loss: 0.2012 - val_accuracy: 0.9371 - val_loss: 0.2053
# Epoch 43/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9361 - loss: 0.2031 - val_accuracy: 0.9384 - val_loss: 0.2059
# Epoch 44/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9368 - loss: 0.2033 - val_accuracy: 0.9353 - val_loss: 0.2056
# Epoch 45/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9350 - loss: 0.2046 - val_accuracy: 0.9369 - val_loss: 0.2064
# Epoch 46/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9384 - loss: 0.1985 - val_accuracy: 0.9381 - val_loss: 0.2061
# Epoch 47/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9368 - loss: 0.2038 - val_accuracy: 0.9373 - val_loss: 0.2059
# Epoch 48/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9355 - loss: 0.2070 - val_accuracy: 0.9371 - val_loss: 0.2051
# Epoch 49/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9354 - loss: 0.2036 - val_accuracy: 0.9360 - val_loss: 0.2064
# Epoch 50/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9373 - loss: 0.2036 - val_accuracy: 0.9338 - val_loss: 0.2066
# Epoch 51/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9341 - loss: 0.2057 - val_accuracy: 0.9368 - val_loss: 0.2055
# Epoch 52/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9364 - loss: 0.2014 - val_accuracy: 0.9372 - val_loss: 0.2047
# Epoch 53/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9366 - loss: 0.2061 - val_accuracy: 0.9361 - val_loss: 0.2069
# Epoch 54/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9380 - loss: 0.2017 - val_accuracy: 0.9384 - val_loss: 0.2054
# Epoch 55/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9397 - loss: 0.1976 - val_accuracy: 0.9367 - val_loss: 0.2056
# Epoch 56/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9365 - loss: 0.2069 - val_accuracy: 0.9338 - val_loss: 0.2052
# Epoch 57/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9381 - loss: 0.2006 - val_accuracy: 0.9357 - val_loss: 0.2047
# Epoch 58/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9391 - loss: 0.1970 - val_accuracy: 0.9392 - val_loss: 0.2055
# Epoch 59/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9390 - loss: 0.2016 - val_accuracy: 0.9368 - val_loss: 0.2057
# Epoch 60/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9371 - loss: 0.2025 - val_accuracy: 0.9350 - val_loss: 0.2056
# Epoch 61/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9380 - loss: 0.2032 - val_accuracy: 0.9338 - val_loss: 0.2061
# Epoch 62/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9371 - loss: 0.2036 - val_accuracy: 0.9333 - val_loss: 0.2053
# Epoch 63/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9365 - loss: 0.2014 - val_accuracy: 0.9365 - val_loss: 0.2067
# Epoch 64/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9359 - loss: 0.2032 - val_accuracy: 0.9373 - val_loss: 0.2052
# Epoch 65/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9394 - loss: 0.1983 - val_accuracy: 0.9372 - val_loss: 0.2058
# Epoch 66/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9366 - loss: 0.2037 - val_accuracy: 0.9350 - val_loss: 0.2061
# Epoch 67/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9351 - loss: 0.2056 - val_accuracy: 0.9379 - val_loss: 0.2052
# Epoch 68/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9386 - loss: 0.1979 - val_accuracy: 0.9337 - val_loss: 0.2052
# Epoch 69/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9359 - loss: 0.2037 - val_accuracy: 0.9367 - val_loss: 0.2059
# Epoch 70/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9369 - loss: 0.2042 - val_accuracy: 0.9326 - val_loss: 0.2051
# Epoch 71/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9360 - loss: 0.2022 - val_accuracy: 0.9373 - val_loss: 0.2061
# Epoch 72/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9355 - loss: 0.2032 - val_accuracy: 0.9360 - val_loss: 0.2047
# Epoch 73/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9384 - loss: 0.1993 - val_accuracy: 0.9377 - val_loss: 0.2048
# Epoch 74/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9373 - loss: 0.2036 - val_accuracy: 0.9367 - val_loss: 0.2044
# Epoch 75/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9375 - loss: 0.2021 - val_accuracy: 0.9371 - val_loss: 0.2060
# Epoch 76/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9401 - loss: 0.1969 - val_accuracy: 0.9368 - val_loss: 0.2055
# Epoch 77/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9368 - loss: 0.2032 - val_accuracy: 0.9357 - val_loss: 0.2056
# Epoch 78/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9358 - loss: 0.2054 - val_accuracy: 0.9327 - val_loss: 0.2049
# Epoch 79/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9407 - loss: 0.1916 - val_accuracy: 0.9363 - val_loss: 0.2058
# Epoch 80/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9362 - loss: 0.2027 - val_accuracy: 0.9377 - val_loss: 0.2059
# Epoch 81/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9379 - loss: 0.2030 - val_accuracy: 0.9365 - val_loss: 0.2071
# Epoch 82/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9372 - loss: 0.1993 - val_accuracy: 0.9363 - val_loss: 0.2065
# Epoch 83/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9368 - loss: 0.2016 - val_accuracy: 0.9395 - val_loss: 0.2050
# Epoch 84/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9383 - loss: 0.2032 - val_accuracy: 0.9372 - val_loss: 0.2061
# Epoch 85/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9374 - loss: 0.2003 - val_accuracy: 0.9373 - val_loss: 0.2053
# Epoch 86/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9366 - loss: 0.2043 - val_accuracy: 0.9372 - val_loss: 0.2052
# Epoch 87/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9398 - loss: 0.1986 - val_accuracy: 0.9354 - val_loss: 0.2060
# Epoch 88/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9377 - loss: 0.2004 - val_accuracy: 0.9376 - val_loss: 0.2044
# Epoch 89/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9395 - loss: 0.1970 - val_accuracy: 0.9376 - val_loss: 0.2044
# Epoch 90/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9377 - loss: 0.2011 - val_accuracy: 0.9358 - val_loss: 0.2054
# Epoch 91/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9375 - loss: 0.2006 - val_accuracy: 0.9363 - val_loss: 0.2049
# Epoch 92/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9363 - loss: 0.2029 - val_accuracy: 0.9352 - val_loss: 0.2047
# Epoch 93/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9344 - loss: 0.2075 - val_accuracy: 0.9380 - val_loss: 0.2056
# Epoch 94/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9355 - loss: 0.2055 - val_accuracy: 0.9372 - val_loss: 0.2043
# Epoch 95/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9365 - loss: 0.2037 - val_accuracy: 0.9368 - val_loss: 0.2039
# Epoch 96/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9378 - loss: 0.2023 - val_accuracy: 0.9376 - val_loss: 0.2051
# Epoch 97/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9384 - loss: 0.1989 - val_accuracy: 0.9372 - val_loss: 0.2053
# Epoch 98/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9374 - loss: 0.2013 - val_accuracy: 0.9357 - val_loss: 0.2042
# Epoch 99/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9368 - loss: 0.2022 - val_accuracy: 0.9373 - val_loss: 0.2060
# Epoch 100/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9380 - loss: 0.2012 - val_accuracy: 0.9372 - val_loss: 0.2041
# Epoch 101/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9409 - loss: 0.1983 - val_accuracy: 0.9352 - val_loss: 0.2054
# Epoch 102/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9373 - loss: 0.2024 - val_accuracy: 0.9379 - val_loss: 0.2044
# Epoch 103/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9397 - loss: 0.1975 - val_accuracy: 0.9365 - val_loss: 0.2054
# Epoch 104/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9367 - loss: 0.2037 - val_accuracy: 0.9367 - val_loss: 0.2052
# Epoch 105/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9387 - loss: 0.2025 - val_accuracy: 0.9356 - val_loss: 0.2045
# Epoch 106/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9400 - loss: 0.1977 - val_accuracy: 0.9342 - val_loss: 0.2036
# Epoch 107/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9394 - loss: 0.1982 - val_accuracy: 0.9372 - val_loss: 0.2054
# Epoch 108/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9361 - loss: 0.2009 - val_accuracy: 0.9354 - val_loss: 0.2069
# Epoch 109/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9378 - loss: 0.2057 - val_accuracy: 0.9376 - val_loss: 0.2054
# Epoch 110/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9385 - loss: 0.2014 - val_accuracy: 0.9352 - val_loss: 0.2075
# Epoch 111/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9394 - loss: 0.1987 - val_accuracy: 0.9361 - val_loss: 0.2053
# Epoch 112/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9363 - loss: 0.2027 - val_accuracy: 0.9352 - val_loss: 0.2062
# Epoch 113/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9398 - loss: 0.2011 - val_accuracy: 0.9376 - val_loss: 0.2047
# Epoch 114/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9376 - loss: 0.2017 - val_accuracy: 0.9363 - val_loss: 0.2053
# Epoch 115/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9384 - loss: 0.2006 - val_accuracy: 0.9391 - val_loss: 0.2045
# Epoch 116/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9354 - loss: 0.2095 - val_accuracy: 0.9376 - val_loss: 0.2045
# Epoch 117/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9395 - loss: 0.1982 - val_accuracy: 0.9372 - val_loss: 0.2052
# Epoch 118/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9390 - loss: 0.1991 - val_accuracy: 0.9354 - val_loss: 0.2046
# Epoch 119/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9379 - loss: 0.2017 - val_accuracy: 0.9341 - val_loss: 0.2047
# Epoch 120/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9379 - loss: 0.2012 - val_accuracy: 0.9361 - val_loss: 0.2044
# Epoch 121/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9402 - loss: 0.1969 - val_accuracy: 0.9340 - val_loss: 0.2049
# Epoch 122/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9372 - loss: 0.2043 - val_accuracy: 0.9367 - val_loss: 0.2041
# Epoch 123/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9355 - loss: 0.2039 - val_accuracy: 0.9380 - val_loss: 0.2048
# Epoch 124/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9379 - loss: 0.1992 - val_accuracy: 0.9357 - val_loss: 0.2060
# Epoch 125/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9374 - loss: 0.2007 - val_accuracy: 0.9372 - val_loss: 0.2050
# Epoch 126/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9370 - loss: 0.2019 - val_accuracy: 0.9377 - val_loss: 0.2049
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step
# Accuracy: 0.9285

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv1D, Flatten, Dense
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score

# Load dataset
file_path = "Downloads/preprocessed_covid500.csv"  # Update with the correct path to your dataset
df = pd.read_csv(file_path)

# Drop the 'source' feature if it exists
# df = df.drop(columns=['source'], errors='ignore')

# Separate features and target variable
X = df.drop(columns=['COVID-19'])
y = df['COVID-19']

# Information Gain Function using SelectKBest
def information_gain(X, y, num_features=10):
    """
    Calculate Information Gain (using mutual information) between features and target variable,
    and return the top num_features based on Information Gain scores.
    
    Parameters:
    - X: DataFrame of features
    - y: Series of target variable
    - num_features: Number of top features to select based on Information Gain
    
    Returns:
    - List of selected feature names
    """
    selector = SelectKBest(score_func=mutual_info_classif, k=num_features)
    selector.fit(X, y)
    selected_indices = selector.get_support(indices=True)
    return X.columns[selected_indices].tolist()  # Return as a list

# Apply Information Gain
num_features_to_select = 10  # Change this to the desired number of features
selected_features = information_gain(X, y, num_features=num_features_to_select)

# Print the features selected by Information Gain
print("Features Selected by Information Gain:")
for feature in selected_features:
    print(feature)

# Filter the dataset to keep only the selected features
X_selected = X[selected_features]

# Prepare Data for 1D CNN
X_selected = X_selected.values.reshape(X_selected.shape[0], X_selected.shape[1], 1)  # Reshape for CNN
y = y.values  # Convert target variable to numpy array

# Split the Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# Build and Train the 1D CNN Model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_selected.shape[1], 1)))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))  # Adjust output layer based on your problem

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model with early stopping
model.fit(X_train, y_train, epochs=10000, batch_size=32, validation_split=0.2, callbacks=[early_stopping])  # Adjust epochs and batch size as needed

# Evaluate the Model
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)  # Convert probabilities to binary class predictions

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_classes)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Features Selected by Information Gain:
# Asthma
# Chronic Lung Disease
# Headache
# Heart Disease
# Diabetes
# Abroad travel
# Contact with COVID Patient
# Attended Large Gathering
# Visited Public Exposed Places
# Family working in Public Exposed Places
# Epoch 1/10000
# C:\Users\aurok\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8779 - loss: 0.3765 - val_accuracy: 0.9215 - val_loss: 0.2042
# Epoch 2/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9311 - loss: 0.1938 - val_accuracy: 0.9267 - val_loss: 0.2037
# Epoch 3/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9348 - loss: 0.1941 - val_accuracy: 0.9384 - val_loss: 0.1938
# Epoch 4/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9384 - loss: 0.1910 - val_accuracy: 0.9399 - val_loss: 0.1915
# Epoch 5/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9420 - loss: 0.1836 - val_accuracy: 0.9407 - val_loss: 0.1915
# Epoch 6/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9426 - loss: 0.1854 - val_accuracy: 0.9404 - val_loss: 0.1889
# Epoch 7/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9427 - loss: 0.1832 - val_accuracy: 0.9407 - val_loss: 0.1915
# Epoch 8/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9444 - loss: 0.1828 - val_accuracy: 0.9408 - val_loss: 0.1904
# Epoch 9/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9434 - loss: 0.1849 - val_accuracy: 0.9412 - val_loss: 0.1872
# Epoch 10/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9428 - loss: 0.1849 - val_accuracy: 0.9422 - val_loss: 0.1866
# Epoch 11/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9421 - loss: 0.1857 - val_accuracy: 0.9439 - val_loss: 0.1880
# Epoch 12/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9460 - loss: 0.1799 - val_accuracy: 0.9390 - val_loss: 0.1869
# Epoch 13/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1814 - val_accuracy: 0.9411 - val_loss: 0.1895
# Epoch 14/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9441 - loss: 0.1812 - val_accuracy: 0.9418 - val_loss: 0.1856
# Epoch 15/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9438 - loss: 0.1833 - val_accuracy: 0.9402 - val_loss: 0.1863
# Epoch 16/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9449 - loss: 0.1769 - val_accuracy: 0.9411 - val_loss: 0.1853
# Epoch 17/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9471 - loss: 0.1733 - val_accuracy: 0.9437 - val_loss: 0.1885
# Epoch 18/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9449 - loss: 0.1800 - val_accuracy: 0.9434 - val_loss: 0.1861
# Epoch 19/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9416 - loss: 0.1853 - val_accuracy: 0.9410 - val_loss: 0.1847
# Epoch 20/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9434 - loss: 0.1822 - val_accuracy: 0.9414 - val_loss: 0.1852
# Epoch 21/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9456 - loss: 0.1779 - val_accuracy: 0.9434 - val_loss: 0.1843
# Epoch 22/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9440 - loss: 0.1807 - val_accuracy: 0.9434 - val_loss: 0.1841
# Epoch 23/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9452 - loss: 0.1775 - val_accuracy: 0.9410 - val_loss: 0.1848
# Epoch 24/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9435 - loss: 0.1836 - val_accuracy: 0.9407 - val_loss: 0.1885
# Epoch 25/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9430 - loss: 0.1830 - val_accuracy: 0.9421 - val_loss: 0.1842
# Epoch 26/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9442 - loss: 0.1818 - val_accuracy: 0.9429 - val_loss: 0.1838
# Epoch 27/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9424 - loss: 0.1835 - val_accuracy: 0.9435 - val_loss: 0.1846
# Epoch 28/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9459 - loss: 0.1765 - val_accuracy: 0.9434 - val_loss: 0.1850
# Epoch 29/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9466 - loss: 0.1767 - val_accuracy: 0.9434 - val_loss: 0.1836
# Epoch 30/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9453 - loss: 0.1781 - val_accuracy: 0.9406 - val_loss: 0.1845
# Epoch 31/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9434 - loss: 0.1798 - val_accuracy: 0.9427 - val_loss: 0.1862
# Epoch 32/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9430 - loss: 0.1817 - val_accuracy: 0.9429 - val_loss: 0.1837
# Epoch 33/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9445 - loss: 0.1785 - val_accuracy: 0.9435 - val_loss: 0.1834
# Epoch 34/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1790 - val_accuracy: 0.9419 - val_loss: 0.1837
# Epoch 35/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1801 - val_accuracy: 0.9433 - val_loss: 0.1843
# Epoch 36/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1812 - val_accuracy: 0.9437 - val_loss: 0.1835
# Epoch 37/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9438 - loss: 0.1810 - val_accuracy: 0.9426 - val_loss: 0.1869
# Epoch 38/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9450 - loss: 0.1815 - val_accuracy: 0.9435 - val_loss: 0.1831
# Epoch 39/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1777 - val_accuracy: 0.9427 - val_loss: 0.1838
# Epoch 40/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9417 - loss: 0.1855 - val_accuracy: 0.9414 - val_loss: 0.1849
# Epoch 41/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1784 - val_accuracy: 0.9421 - val_loss: 0.1842
# Epoch 42/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1796 - val_accuracy: 0.9437 - val_loss: 0.1852
# Epoch 43/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9466 - loss: 0.1786 - val_accuracy: 0.9433 - val_loss: 0.1838
# Epoch 44/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9447 - loss: 0.1794 - val_accuracy: 0.9421 - val_loss: 0.1838
# Epoch 45/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9425 - loss: 0.1804 - val_accuracy: 0.9437 - val_loss: 0.1845
# Epoch 46/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9479 - loss: 0.1742 - val_accuracy: 0.9438 - val_loss: 0.1830
# Epoch 47/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9440 - loss: 0.1806 - val_accuracy: 0.9429 - val_loss: 0.1842
# Epoch 48/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9450 - loss: 0.1820 - val_accuracy: 0.9430 - val_loss: 0.1834
# Epoch 49/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9423 - loss: 0.1851 - val_accuracy: 0.9434 - val_loss: 0.1836
# Epoch 50/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9426 - loss: 0.1831 - val_accuracy: 0.9434 - val_loss: 0.1839
# Epoch 51/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9405 - loss: 0.1897 - val_accuracy: 0.9427 - val_loss: 0.1854
# Epoch 52/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9450 - loss: 0.1791 - val_accuracy: 0.9423 - val_loss: 0.1841
# Epoch 53/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9425 - loss: 0.1817 - val_accuracy: 0.9431 - val_loss: 0.1845
# Epoch 54/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9463 - loss: 0.1774 - val_accuracy: 0.9421 - val_loss: 0.1831
# Epoch 55/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9443 - loss: 0.1800 - val_accuracy: 0.9433 - val_loss: 0.1829
# Epoch 56/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9446 - loss: 0.1772 - val_accuracy: 0.9414 - val_loss: 0.1850
# Epoch 57/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9436 - loss: 0.1824 - val_accuracy: 0.9442 - val_loss: 0.1840
# Epoch 58/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9463 - loss: 0.1782 - val_accuracy: 0.9417 - val_loss: 0.1836
# Epoch 59/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9463 - loss: 0.1757 - val_accuracy: 0.9439 - val_loss: 0.1834
# Epoch 60/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9453 - loss: 0.1819 - val_accuracy: 0.9426 - val_loss: 0.1835
# Epoch 61/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9439 - loss: 0.1822 - val_accuracy: 0.9433 - val_loss: 0.1840
# Epoch 62/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9463 - loss: 0.1751 - val_accuracy: 0.9435 - val_loss: 0.1833
# Epoch 63/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9447 - loss: 0.1811 - val_accuracy: 0.9430 - val_loss: 0.1826
# Epoch 64/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9445 - loss: 0.1813 - val_accuracy: 0.9422 - val_loss: 0.1829
# Epoch 65/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9456 - loss: 0.1760 - val_accuracy: 0.9431 - val_loss: 0.1833
# Epoch 66/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9458 - loss: 0.1763 - val_accuracy: 0.9433 - val_loss: 0.1840
# Epoch 67/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9438 - loss: 0.1832 - val_accuracy: 0.9437 - val_loss: 0.1836
# Epoch 68/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1781 - val_accuracy: 0.9438 - val_loss: 0.1841
# Epoch 69/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9460 - loss: 0.1795 - val_accuracy: 0.9414 - val_loss: 0.1842
# Epoch 70/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9460 - loss: 0.1774 - val_accuracy: 0.9412 - val_loss: 0.1848
# Epoch 71/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9448 - loss: 0.1816 - val_accuracy: 0.9421 - val_loss: 0.1824
# Epoch 72/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9462 - loss: 0.1766 - val_accuracy: 0.9439 - val_loss: 0.1835
# Epoch 73/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9442 - loss: 0.1809 - val_accuracy: 0.9423 - val_loss: 0.1835
# Epoch 74/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9439 - loss: 0.1826 - val_accuracy: 0.9431 - val_loss: 0.1834
# Epoch 75/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9454 - loss: 0.1756 - val_accuracy: 0.9430 - val_loss: 0.1830
# Epoch 76/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9441 - loss: 0.1838 - val_accuracy: 0.9427 - val_loss: 0.1840
# Epoch 77/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9441 - loss: 0.1805 - val_accuracy: 0.9444 - val_loss: 0.1845
# Epoch 78/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9438 - loss: 0.1815 - val_accuracy: 0.9408 - val_loss: 0.1857
# Epoch 79/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1828 - val_accuracy: 0.9439 - val_loss: 0.1832
# Epoch 80/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9458 - loss: 0.1790 - val_accuracy: 0.9444 - val_loss: 0.1839
# Epoch 81/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1794 - val_accuracy: 0.9441 - val_loss: 0.1828
# Epoch 82/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9426 - loss: 0.1878 - val_accuracy: 0.9439 - val_loss: 0.1832
# Epoch 83/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1825 - val_accuracy: 0.9434 - val_loss: 0.1877
# Epoch 84/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9430 - loss: 0.1864 - val_accuracy: 0.9444 - val_loss: 0.1827
# Epoch 85/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9456 - loss: 0.1766 - val_accuracy: 0.9431 - val_loss: 0.1828
# Epoch 86/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9424 - loss: 0.1833 - val_accuracy: 0.9441 - val_loss: 0.1828
# Epoch 87/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9443 - loss: 0.1834 - val_accuracy: 0.9444 - val_loss: 0.1830
# Epoch 88/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9471 - loss: 0.1757 - val_accuracy: 0.9441 - val_loss: 0.1835
# Epoch 89/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9439 - loss: 0.1818 - val_accuracy: 0.9442 - val_loss: 0.1826
# Epoch 90/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9424 - loss: 0.1836 - val_accuracy: 0.9439 - val_loss: 0.1844
# Epoch 91/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1807 - val_accuracy: 0.9435 - val_loss: 0.1821
# Epoch 92/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9457 - loss: 0.1761 - val_accuracy: 0.9444 - val_loss: 0.1838
# Epoch 93/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9479 - loss: 0.1755 - val_accuracy: 0.9410 - val_loss: 0.1833
# Epoch 94/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9462 - loss: 0.1745 - val_accuracy: 0.9435 - val_loss: 0.1832
# Epoch 95/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9457 - loss: 0.1788 - val_accuracy: 0.9417 - val_loss: 0.1867
# Epoch 96/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9451 - loss: 0.1792 - val_accuracy: 0.9430 - val_loss: 0.1826
# Epoch 97/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9430 - loss: 0.1836 - val_accuracy: 0.9426 - val_loss: 0.1834
# Epoch 98/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9455 - loss: 0.1762 - val_accuracy: 0.9430 - val_loss: 0.1828
# Epoch 99/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9440 - loss: 0.1808 - val_accuracy: 0.9437 - val_loss: 0.1843
# Epoch 100/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9443 - loss: 0.1802 - val_accuracy: 0.9444 - val_loss: 0.1835
# Epoch 101/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9465 - loss: 0.1780 - val_accuracy: 0.9435 - val_loss: 0.1833
# Epoch 102/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9441 - loss: 0.1806 - val_accuracy: 0.9435 - val_loss: 0.1829
# Epoch 103/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9467 - loss: 0.1748 - val_accuracy: 0.9427 - val_loss: 0.1830
# Epoch 104/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9453 - loss: 0.1788 - val_accuracy: 0.9445 - val_loss: 0.1851
# Epoch 105/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9450 - loss: 0.1816 - val_accuracy: 0.9437 - val_loss: 0.1838
# Epoch 106/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9455 - loss: 0.1773 - val_accuracy: 0.9437 - val_loss: 0.1834
# Epoch 107/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9446 - loss: 0.1825 - val_accuracy: 0.9425 - val_loss: 0.1839
# Epoch 108/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9439 - loss: 0.1827 - val_accuracy: 0.9431 - val_loss: 0.1821
# Epoch 109/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9445 - loss: 0.1817 - val_accuracy: 0.9429 - val_loss: 0.1833
# Epoch 110/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9445 - loss: 0.1805 - val_accuracy: 0.9442 - val_loss: 0.1823
# Epoch 111/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9445 - loss: 0.1790 - val_accuracy: 0.9431 - val_loss: 0.1845
# Epoch 112/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9415 - loss: 0.1875 - val_accuracy: 0.9454 - val_loss: 0.1826
# Epoch 113/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9466 - loss: 0.1766 - val_accuracy: 0.9435 - val_loss: 0.1847
# Epoch 114/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9453 - loss: 0.1797 - val_accuracy: 0.9422 - val_loss: 0.1826
# Epoch 115/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9453 - loss: 0.1798 - val_accuracy: 0.9426 - val_loss: 0.1825
# Epoch 116/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9459 - loss: 0.1772 - val_accuracy: 0.9442 - val_loss: 0.1832
# Epoch 117/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9462 - loss: 0.1789 - val_accuracy: 0.9429 - val_loss: 0.1826
# Epoch 118/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9455 - loss: 0.1777 - val_accuracy: 0.9445 - val_loss: 0.1851
# Epoch 119/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9470 - loss: 0.1752 - val_accuracy: 0.9435 - val_loss: 0.1824
# Epoch 120/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1807 - val_accuracy: 0.9439 - val_loss: 0.1826
# Epoch 121/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9455 - loss: 0.1773 - val_accuracy: 0.9429 - val_loss: 0.1856
# Epoch 122/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9482 - loss: 0.1709 - val_accuracy: 0.9439 - val_loss: 0.1818
# Epoch 123/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9437 - loss: 0.1827 - val_accuracy: 0.9458 - val_loss: 0.1823
# Epoch 124/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9474 - loss: 0.1752 - val_accuracy: 0.9425 - val_loss: 0.1840
# Epoch 125/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9453 - loss: 0.1797 - val_accuracy: 0.9446 - val_loss: 0.1850
# Epoch 126/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9467 - loss: 0.1765 - val_accuracy: 0.9450 - val_loss: 0.1819
# Epoch 127/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9455 - loss: 0.1775 - val_accuracy: 0.9439 - val_loss: 0.1828
# Epoch 128/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9448 - loss: 0.1786 - val_accuracy: 0.9441 - val_loss: 0.1826
# Epoch 129/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9450 - loss: 0.1802 - val_accuracy: 0.9437 - val_loss: 0.1823
# Epoch 130/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9446 - loss: 0.1804 - val_accuracy: 0.9442 - val_loss: 0.1833
# Epoch 131/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1835 - val_accuracy: 0.9438 - val_loss: 0.1852
# Epoch 132/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9454 - loss: 0.1818 - val_accuracy: 0.9439 - val_loss: 0.1822
# Epoch 133/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9452 - loss: 0.1782 - val_accuracy: 0.9410 - val_loss: 0.1830
# Epoch 134/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9447 - loss: 0.1792 - val_accuracy: 0.9427 - val_loss: 0.1821
# Epoch 135/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1831 - val_accuracy: 0.9457 - val_loss: 0.1821
# Epoch 136/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9440 - loss: 0.1800 - val_accuracy: 0.9426 - val_loss: 0.1833
# Epoch 137/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9439 - loss: 0.1851 - val_accuracy: 0.9441 - val_loss: 0.1832
# Epoch 138/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9463 - loss: 0.1789 - val_accuracy: 0.9433 - val_loss: 0.1824
# Epoch 139/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9474 - loss: 0.1733 - val_accuracy: 0.9410 - val_loss: 0.1822
# Epoch 140/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9452 - loss: 0.1783 - val_accuracy: 0.9445 - val_loss: 0.1819
# Epoch 141/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9447 - loss: 0.1805 - val_accuracy: 0.9450 - val_loss: 0.1824
# Epoch 142/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9459 - loss: 0.1793 - val_accuracy: 0.9442 - val_loss: 0.1817
# Epoch 143/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9462 - loss: 0.1760 - val_accuracy: 0.9430 - val_loss: 0.1895
# Epoch 144/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9449 - loss: 0.1841 - val_accuracy: 0.9425 - val_loss: 0.1825
# Epoch 145/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9470 - loss: 0.1778 - val_accuracy: 0.9438 - val_loss: 0.1822
# Epoch 146/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9442 - loss: 0.1823 - val_accuracy: 0.9434 - val_loss: 0.1828
# Epoch 147/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9450 - loss: 0.1804 - val_accuracy: 0.9448 - val_loss: 0.1828
# Epoch 148/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9434 - loss: 0.1833 - val_accuracy: 0.9445 - val_loss: 0.1831
# Epoch 149/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9445 - loss: 0.1812 - val_accuracy: 0.9438 - val_loss: 0.1822
# Epoch 150/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9450 - loss: 0.1761 - val_accuracy: 0.9441 - val_loss: 0.1822
# Epoch 151/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9453 - loss: 0.1802 - val_accuracy: 0.9429 - val_loss: 0.1822
# Epoch 152/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9465 - loss: 0.1773 - val_accuracy: 0.9410 - val_loss: 0.1837
# Epoch 153/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9446 - loss: 0.1810 - val_accuracy: 0.9441 - val_loss: 0.1818
# Epoch 154/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9439 - loss: 0.1821 - val_accuracy: 0.9448 - val_loss: 0.1823
# Epoch 155/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9453 - loss: 0.1797 - val_accuracy: 0.9444 - val_loss: 0.1819
# Epoch 156/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9457 - loss: 0.1775 - val_accuracy: 0.9453 - val_loss: 0.1823
# Epoch 157/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9468 - loss: 0.1788 - val_accuracy: 0.9445 - val_loss: 0.1830
# Epoch 158/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9458 - loss: 0.1776 - val_accuracy: 0.9441 - val_loss: 0.1817
# Epoch 159/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9448 - loss: 0.1827 - val_accuracy: 0.9438 - val_loss: 0.1820
# Epoch 160/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9463 - loss: 0.1787 - val_accuracy: 0.9441 - val_loss: 0.1819
# Epoch 161/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9453 - loss: 0.1785 - val_accuracy: 0.9429 - val_loss: 0.1836
# Epoch 162/10000
# 926/926 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9471 - loss: 0.1767 - val_accuracy: 0.9441 - val_loss: 0.1827
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 0.9404

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv1D, Flatten, Dense, Input
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score

# Load dataset
file_path = "Downloads/preprocessed_covid500.csv"  # Update with the correct path to your dataset
df = pd.read_csv(file_path)

# Drop the 'source' feature if it exists
# df = df.drop(columns=['source'], errors='ignore')

# Separate features and target variable
X = df.drop(columns=['COVID-19'])
y = df['COVID-19']

# Cumulative Feature Selection Function
def cumulative_feature_selection(X, y, max_features=10):
    selected_features = []
    feature_indices = list(range(X.shape[1]))
    
    for _ in range(max_features):
        best_accuracy = 0
        best_feature = None
        
        for i in feature_indices:
            # Temporarily add the feature
            temp_features = selected_features + [X.columns[i]]
            X_temp = X[temp_features].values.reshape(X.shape[0], len(temp_features), 1)
            
            # Split the data
            X_train, X_test, y_train, y_test = train_test_split(X_temp, y, test_size=0.2, random_state=42)
            
            # Build and train the model
            model = Sequential()
            model.add(Input(shape=(len(temp_features), 1)))  # Use Input layer to define input shape
            model.add(Conv1D(filters=64, kernel_size=1, activation='relu'))  # Use kernel_size=1 for single feature
            model.add(Flatten())
            model.add(Dense(1, activation='sigmoid'))  # Adjust output layer based on your problem
            
            model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
            
            # Early stopping callback
            early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
            
            # Fit the model
            model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2, callbacks=[early_stopping], verbose=0)
            
            # Evaluate the model
            y_pred = model.predict(X_test)
            y_pred_classes = (y_pred > 0.5).astype(int)
            accuracy = accuracy_score(y_test, y_pred_classes)
            
            # Check if this feature improves accuracy
            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_feature = X.columns[i]
        
        # Add the best feature found in this iteration
        if best_feature is not None:
            selected_features.append(best_feature)
            feature_indices.remove(X.columns.get_loc(best_feature))  # Remove the selected feature from the pool
            print(f"Selected feature: {best_feature} with accuracy: {best_accuracy:.4f}")
    
    return selected_features

# Apply Cumulative Feature Selection
max_features_to_select = 10  # Change this to the desired maximum number of features
selected_features = cumulative_feature_selection(X, y, max_features=max_features_to_select)

# Print the features selected by Cumulative Feature Selection
print("Features Selected by Cumulative Feature Selection:")
for feature in selected_features:
    print(feature)

# Filter the dataset to keep only the selected features
X_selected = X[selected_features]

# Prepare Data for 1D CNN
X_selected = X_selected.values.reshape(X_selected.shape[0], X_selected.shape[1], 1)  # Reshape for CNN
y = y.values  # Convert target variable to numpy array

# Split the Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# Build and Train the 1D CNN Model
model = Sequential()
model.add(Input(shape=(X_selected.shape[1], 1)))  # Use Input layer to define input shape
model.add(Conv1D(filters=64, kernel_size=1, activation='relu'))  # Use kernel_size=1 for single feature
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))  # Adjust output layer based on your problem

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model
model.fit(X_train, y_train, epochs=10000, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

# Evaluate the Model
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)  # Convert probabilities to binary class predictions

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_classes)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 71
#      69 # Apply Cumulative Feature Selection
#      70 max_features_to_select = 10  # Change this to the desired maximum number of features
# ---> 71 selected_features = cumulative_feature_selection(X, y, max_features=max_features_to_select)
#      73 # Print the features selected by Cumulative Feature Selection
#      74 print("Features Selected by Cumulative Feature Selection:")
#
# Cell In[30], line 49, in cumulative_feature_selection(X, y, max_features)
#      46 early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
#      48 # Fit the model
# ---> 49 model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2, callbacks=[early_stopping], verbose=0)
#      51 # Evaluate the model
#      52 y_pred = model.predict(X_test)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:343, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     332 if getattr(self, "_eval_epoch_iterator", None) is None:
#     333     self._eval_epoch_iterator = TFEpochIterator(
#     334         x=val_x,
#     335         y=val_y,
#    (...)
#     341         shuffle=False,
#     342     )
# --> 343 val_logs = self.evaluate(
#     344     x=val_x,
#     345     y=val_y,
#     346     sample_weight=val_sample_weight,
#     347     batch_size=validation_batch_size or batch_size,
#     348     steps=validation_steps,
#     349     callbacks=callbacks,
#     350     return_dict=True,
#     351     _use_cached_eval_dataset=True,
#     352 )
#     353 val_logs = {
#     354     "val_" + name: val for name, val in val_logs.items()
#     355 }
#     356 epoch_logs.update(val_logs)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:429, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     427 for step, iterator in epoch_iterator.enumerate_epoch():
#     428     callbacks.on_test_batch_begin(step)
# --> 429     logs = self.test_function(iterator)
#     430     logs = self._pythonify_logs(logs)
#     431     callbacks.on_test_batch_end(step, logs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import warnings
from sklearn.model_selection import KFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    confusion_matrix, matthews_corrcoef
)
from keras.models import Sequential, save_model
from keras.layers import Dense, Dropout, Flatten
from keras.callbacks import EarlyStopping
import tensorflow as tf

warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Load dataset
def load_data(file_path):
    print("Loading dataset...")
    df = pd.read_csv(file_path)
    
    # Use only the specified features
    selected_features = [
        'Breathing Problem', 'Sore throat', 'Running Nose', 'Chronic Lung Disease',
        'Headache', 'Heart Disease', 'Diabetes', 'Hyper Tension', 'Attended Large Gathering', 'Gastrointestinal '
    ]
    
    # Check if all selected features are in the dataframe
    missing_features = [f for f in selected_features if f not in df.columns]
    if missing_features:
        raise ValueError(f"The following features are missing from the dataset: {missing_features}")
    
    X = df[selected_features].values.reshape(-1, 10, 1, 1)  # Reshape for ANN input
    y = df['COVID-19'].values
    
    print(f"Dataset loaded: {X.shape[0]} samples, {X.shape[1]} features")
    print(f"Class distribution: {dict(pd.Series(y).value_counts())}")
    print(f"Selected features: {', '.join(selected_features)}")
    
    return X, y

# Build the ANN model with industry-standard parameters
def create_ann_model():
    # Industry-standard parameters
    dropout1 = 0.3  # Standard dropout rate for first layer
    dropout2 = 0.5  # Higher dropout for deeper layers
    
    model = Sequential([
        Flatten(input_shape=(10, 1, 1)),  # Flatten the input
        Dense(128, activation='relu'),  # First hidden layer with more neurons
        Dropout(dropout1),
        Dense(256, activation='relu'),  # Second hidden layer with more capacity
        Dropout(dropout2),
        Dense(128, activation='relu'),  # Additional layer for better feature extraction
        Dropout(dropout2),
        Dense(1, activation='sigmoid')  # Output layer
    ])
    
    # Industry-standard optimizer settings
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
    
    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# Calculate additional metrics
def calculate_metrics(y_true, y_pred, y_pred_proba):
    # Basic metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    mcc = matthews_corrcoef(y_true, y_pred)
    
    # AUC-ROC
    try:
        roc_auc = roc_auc_score(y_true, y_pred_proba)
    except:
        roc_auc = 0.5
    
    # Confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    
    # False Positive Rate
    fpr = fp / (fp + tn)
    
    # Likelihood Ratios
    sensitivity = recall
    specificity = tn / (tn + fp)
    lr_plus = sensitivity / (1 - specificity) if (1 - specificity) > 0 else float('inf')
    lr_minus = (1 - sensitivity) / specificity if specificity > 0 else float('inf')
    
    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'mcc': mcc,
        'auc': roc_auc,
        'fpr': fpr,
        'specificity': specificity,
        'lr_plus': lr_plus,
        'lr_minus': lr_minus
    }

# Create output directory
def create_output_directory():
    # Create a local directory for outputs
    output_dir = "covid_ann_results"
    
    # Create the directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Created output directory: {output_dir}")
    else:
        print(f"Output directory already exists: {output_dir}")
    
    return output_dir

def main():
    # Create output directory
    output_dir = create_output_directory()
    print(f"Results will be saved in: {output_dir}")
    
    # Load data - using your local path
    file_path = "OneDrive/Desktop/Research_Capstone_Project/preprocessed_covid500_final.csv"
    X, y = load_data(file_path)
    
    # 10-fold cross-validation
    kf = KFold(n_splits=10, shuffle=True, random_state=42)
    
    # Store results
    all_metrics = []
    all_fold_histories = []
    
    # For each fold
    for fold, (train_idx, test_idx) in enumerate(kf.split(X)):
        print(f"\nFold {fold+1}/10")
        print("="*50)
        
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        
        # Create model with industry-standard parameters
        model = create_ann_model()
        
        # Early stopping callback with industry-standard settings
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=15,  # More patience for better convergence
            verbose=1,
            mode='min',
            restore_best_weights=True
        )
        
        # Train the model with industry-standard settings
        history = model.fit(
            X_train, y_train,
            epochs=200,  # Higher max epochs with early stopping
            batch_size=64,  # Larger batch size for better stability
            validation_split=0.2,
            callbacks=[early_stopping],
            verbose=1
        )
        
        all_fold_histories.append(history.history)
        
        # Generate predictions
        y_pred_proba = model.predict(X_test).flatten()
        y_pred = (y_pred_proba > 0.5).astype(int)
        
        # Calculate metrics
        fold_metrics = calculate_metrics(y_test, y_pred, y_pred_proba)
        all_metrics.append(fold_metrics)
        
        # Print metrics for this fold
        print(f"\nMetrics for fold {fold+1}:")
        for metric, value in fold_metrics.items():
            print(f"{metric}: {value:.4f}")
        
        # Removed the individual fold model saving
    
    # Train final model on the entire dataset
    print("\nTraining final model on entire dataset...")
    final_model = create_ann_model()
    
    # Train the final model
    final_early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=15,
        verbose=1,
        mode='min',
        restore_best_weights=True
    )
    
    final_history = final_model.fit(
        X, y,
        epochs=200,
        batch_size=64,
        verbose=1,
        validation_split=0.2,
        callbacks=[final_early_stopping]
    )
    
    # Save only the final model
    model_path = os.path.join(output_dir, "final_model.h5")
    save_model(final_model, model_path)
    print(f"Final model saved to {model_path}")
    
    # Calculate and print average metrics
    metrics_df = pd.DataFrame(all_metrics)
    avg_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()
    
    # Print final summary
    print("\n" + "="*50)
    print("FINAL SUMMARY")
    print("="*50)
    
    print("\nModel Architecture:")
    final_model.summary()
    
    print("\nIndustry-Standard Parameters Used:")
    print("- Dropout rates: 0.3 (first layer), 0.5 (deeper layers)")
    print("- Learning rate: 0.001")
    print("- Batch size: 64")
    print("- Network architecture: 128-256-128-1 neurons")
    print("- Early stopping patience: 15 epochs")
    print("- Max epochs: 200")
    
    print("\nAverage metrics across all folds:")
    for metric in metrics_df.columns:
        print(f"{metric}: {avg_metrics[metric]:.4f} ± {std_metrics[metric]:.4f}")
    
    # Save metrics to CSV
    metrics_df.to_csv(os.path.join(output_dir, "all_fold_metrics.csv"), index=False)
    
    # Save summary metrics
    summary_df = pd.DataFrame({
        'Metric': metrics_df.columns,
        'Mean': avg_metrics.values,
        'Std': std_metrics.values
    })
    summary_df.to_csv(os.path.join(output_dir, "summary_metrics.csv"), index=False)
    
    # Plot training history for final model
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(final_history.history['loss'], label='Training Loss')
    plt.plot(final_history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Curves')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(final_history.history['accuracy'], label='Training Accuracy')
    plt.plot(final_history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy Curves')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "training_history.png"))
    
    # Create a fold comparison plot
    plt.figure(figsize=(15, 10))
    
    # Plot metrics across folds
    metrics_to_plot = ['accuracy', 'precision', 'recall', 'f1', 'auc']
    for i, metric in enumerate(metrics_to_plot):
        plt.subplot(2, 3, i+1)
        plt.bar(range(1, 11), metrics_df[metric], color='skyblue')
        plt.axhline(avg_metrics[metric], color='red', linestyle='--', label=f'Mean: {avg_metrics[metric]:.4f}')
        plt.title(f'{metric.capitalize()} by Fold')
        plt.xlabel('Fold')
        plt.ylabel(metric.capitalize())
        plt.xticks(range(1, 11))
        plt.legend()
    
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "fold_comparison.png"))
    
    print(f"\nAll results and model saved to: {output_dir}")
    print(f"\nFull path to output directory: {os.path.abspath(output_dir)}")

if __name__ == "__main__":
    main()
# Out:
# Output directory already exists: covid_ann_results
# Results will be saved in: covid_ann_results
# Loading dataset...
# Dataset loaded: 37028 samples, 10 features
# Class distribution: {1: 18514, 0: 18514}
# Selected features: Breathing Problem, Sore throat, Running Nose, Chronic Lung Disease, Headache, Heart Disease, Diabetes, Hyper Tension, Attended Large Gathering, Gastrointestinal
#
# Fold 1/10
# ==================================================
# Epoch 1/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9043 - loss: 0.2385 - val_accuracy: 0.9605 - val_loss: 0.1205
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9618 - loss: 0.1010 - val_accuracy: 0.9565 - val_loss: 0.1216
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9682 - loss: 0.0869 - val_accuracy: 0.9616 - val_loss: 0.1030
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9713 - loss: 0.0766 - val_accuracy: 0.9641 - val_loss: 0.1008
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9750 - loss: 0.0727 - val_accuracy: 0.9652 - val_loss: 0.0836
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9754 - loss: 0.0679 - val_accuracy: 0.9638 - val_loss: 0.0887
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9776 - loss: 0.0653 - val_accuracy: 0.9697 - val_loss: 0.0730
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9784 - loss: 0.0621 - val_accuracy: 0.9719 - val_loss: 0.0734
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9788 - loss: 0.0621 - val_accuracy: 0.9728 - val_loss: 0.0666
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9808 - loss: 0.0590 - val_accuracy: 0.9727 - val_loss: 0.0636
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9813 - loss: 0.0584 - val_accuracy: 0.9724 - val_loss: 0.0691
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9816 - loss: 0.0589 - val_accuracy: 0.9736 - val_loss: 0.0518
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9817 - loss: 0.0553 - val_accuracy: 0.9736 - val_loss: 0.0642
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9818 - loss: 0.0524 - val_accuracy: 0.9728 - val_loss: 0.0655
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9811 - loss: 0.0540 - val_accuracy: 0.9736 - val_loss: 0.0594
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9822 - loss: 0.0518 - val_accuracy: 0.9743 - val_loss: 0.0560
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9829 - loss: 0.0556 - val_accuracy: 0.9748 - val_loss: 0.0609
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9826 - loss: 0.0543 - val_accuracy: 0.9739 - val_loss: 0.0567
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9816 - loss: 0.0510 - val_accuracy: 0.9736 - val_loss: 0.0561
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9828 - loss: 0.0491 - val_accuracy: 0.9743 - val_loss: 0.0573
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9829 - loss: 0.0492 - val_accuracy: 0.9748 - val_loss: 0.0591
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9817 - loss: 0.0507 - val_accuracy: 0.9748 - val_loss: 0.0581
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9831 - loss: 0.0492 - val_accuracy: 0.9637 - val_loss: 0.0584
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9822 - loss: 0.0515 - val_accuracy: 0.9749 - val_loss: 0.0610
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9834 - loss: 0.0490 - val_accuracy: 0.9640 - val_loss: 0.0578
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9837 - loss: 0.0462 - val_accuracy: 0.9751 - val_loss: 0.0569
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9835 - loss: 0.0498 - val_accuracy: 0.9742 - val_loss: 0.0603
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# Metrics for fold 1:
# accuracy: 0.9814
# precision: 0.9956
# recall: 0.9677
# f1: 0.9815
# mcc: 0.9631
# auc: 0.9986
# fpr: 0.0044
# specificity: 0.9956
# lr_plus: 219.4277
# lr_minus: 0.0324
#
# Fold 2/10
# ==================================================
# Epoch 1/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9141 - loss: 0.2158 - val_accuracy: 0.9629 - val_loss: 0.0974
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9618 - loss: 0.0988 - val_accuracy: 0.9676 - val_loss: 0.0852
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9718 - loss: 0.0780 - val_accuracy: 0.9674 - val_loss: 0.0839
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9733 - loss: 0.0722 - val_accuracy: 0.9706 - val_loss: 0.0780
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9776 - loss: 0.0638 - val_accuracy: 0.9665 - val_loss: 0.0713
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9782 - loss: 0.0628 - val_accuracy: 0.9724 - val_loss: 0.0727
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9790 - loss: 0.0594 - val_accuracy: 0.9721 - val_loss: 0.0754
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9791 - loss: 0.0581 - val_accuracy: 0.9742 - val_loss: 0.0683
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9799 - loss: 0.0556 - val_accuracy: 0.9724 - val_loss: 0.0653
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9802 - loss: 0.0537 - val_accuracy: 0.9748 - val_loss: 0.0698
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9822 - loss: 0.0537 - val_accuracy: 0.9727 - val_loss: 0.0668
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9821 - loss: 0.0520 - val_accuracy: 0.9749 - val_loss: 0.0689
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9824 - loss: 0.0498 - val_accuracy: 0.9713 - val_loss: 0.0685
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9838 - loss: 0.0495 - val_accuracy: 0.9751 - val_loss: 0.0655
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9834 - loss: 0.0488 - val_accuracy: 0.9727 - val_loss: 0.0627
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9828 - loss: 0.0503 - val_accuracy: 0.9755 - val_loss: 0.0600
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9837 - loss: 0.0503 - val_accuracy: 0.9725 - val_loss: 0.0615
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9832 - loss: 0.0481 - val_accuracy: 0.9755 - val_loss: 0.0599
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9831 - loss: 0.0495 - val_accuracy: 0.9725 - val_loss: 0.0616
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9832 - loss: 0.0470 - val_accuracy: 0.9716 - val_loss: 0.0657
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9837 - loss: 0.0475 - val_accuracy: 0.9754 - val_loss: 0.0604
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9832 - loss: 0.0468 - val_accuracy: 0.9752 - val_loss: 0.0607
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9832 - loss: 0.0462 - val_accuracy: 0.9724 - val_loss: 0.0650
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9841 - loss: 0.0463 - val_accuracy: 0.9722 - val_loss: 0.0624
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9841 - loss: 0.0457 - val_accuracy: 0.9719 - val_loss: 0.0626
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9832 - loss: 0.0463 - val_accuracy: 0.9754 - val_loss: 0.0547
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9837 - loss: 0.0453 - val_accuracy: 0.9718 - val_loss: 0.0624
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9841 - loss: 0.0452 - val_accuracy: 0.9730 - val_loss: 0.0620
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9839 - loss: 0.0459 - val_accuracy: 0.9722 - val_loss: 0.0630
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9840 - loss: 0.0453 - val_accuracy: 0.9722 - val_loss: 0.0627
# Epoch 31/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9843 - loss: 0.0442 - val_accuracy: 0.9758 - val_loss: 0.0601
# Epoch 32/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9851 - loss: 0.0439 - val_accuracy: 0.9737 - val_loss: 0.0606
# Epoch 33/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9847 - loss: 0.0442 - val_accuracy: 0.9728 - val_loss: 0.0622
# Epoch 34/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9852 - loss: 0.0441 - val_accuracy: 0.9719 - val_loss: 0.0648
# Epoch 35/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9840 - loss: 0.0436 - val_accuracy: 0.9730 - val_loss: 0.0614
# Epoch 36/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9843 - loss: 0.0442 - val_accuracy: 0.9760 - val_loss: 0.0589
# Epoch 37/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9844 - loss: 0.0435 - val_accuracy: 0.9731 - val_loss: 0.0584
# Epoch 38/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9841 - loss: 0.0438 - val_accuracy: 0.9733 - val_loss: 0.0581
# Epoch 39/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9840 - loss: 0.0431 - val_accuracy: 0.9733 - val_loss: 0.0611
# Epoch 40/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9846 - loss: 0.0458 - val_accuracy: 0.9731 - val_loss: 0.0612
# Epoch 41/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9843 - loss: 0.0448 - val_accuracy: 0.9755 - val_loss: 0.0605
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Metrics for fold 2:
# accuracy: 0.9776
# precision: 0.9856
# recall: 0.9689
# f1: 0.9771
# mcc: 0.9553
# auc: 0.9981
# fpr: 0.0139
# specificity: 0.9861
# lr_plus: 69.7586
# lr_minus: 0.0316
#
# Fold 3/10
# ==================================================
# Epoch 1/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9136 - loss: 0.2191 - val_accuracy: 0.9586 - val_loss: 0.1127
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9631 - loss: 0.1009 - val_accuracy: 0.9655 - val_loss: 0.1045
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9695 - loss: 0.0821 - val_accuracy: 0.9604 - val_loss: 0.1010
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9730 - loss: 0.0721 - val_accuracy: 0.9662 - val_loss: 0.0893
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9754 - loss: 0.0665 - val_accuracy: 0.9700 - val_loss: 0.0802
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9768 - loss: 0.0625 - val_accuracy: 0.9698 - val_loss: 0.0738
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9784 - loss: 0.0601 - val_accuracy: 0.9592 - val_loss: 0.0787
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9801 - loss: 0.0584 - val_accuracy: 0.9623 - val_loss: 0.0772
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9789 - loss: 0.0556 - val_accuracy: 0.9698 - val_loss: 0.0731
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9807 - loss: 0.0541 - val_accuracy: 0.9694 - val_loss: 0.0750
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9824 - loss: 0.0518 - val_accuracy: 0.9716 - val_loss: 0.0695
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9814 - loss: 0.0508 - val_accuracy: 0.9721 - val_loss: 0.0675
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9817 - loss: 0.0516 - val_accuracy: 0.9727 - val_loss: 0.0667
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9811 - loss: 0.0504 - val_accuracy: 0.9725 - val_loss: 0.0642
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9817 - loss: 0.0503 - val_accuracy: 0.9659 - val_loss: 0.0700
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9817 - loss: 0.0501 - val_accuracy: 0.9725 - val_loss: 0.0626
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9820 - loss: 0.0483 - val_accuracy: 0.9724 - val_loss: 0.0654
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9825 - loss: 0.0480 - val_accuracy: 0.9730 - val_loss: 0.0659
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9821 - loss: 0.0483 - val_accuracy: 0.9622 - val_loss: 0.0696
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9830 - loss: 0.0468 - val_accuracy: 0.9734 - val_loss: 0.0614
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9829 - loss: 0.0472 - val_accuracy: 0.9638 - val_loss: 0.0627
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9836 - loss: 0.0474 - val_accuracy: 0.9730 - val_loss: 0.0637
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9830 - loss: 0.0468 - val_accuracy: 0.9763 - val_loss: 0.0579
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9826 - loss: 0.0475 - val_accuracy: 0.9736 - val_loss: 0.0655
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9836 - loss: 0.0447 - val_accuracy: 0.9724 - val_loss: 0.0621
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9829 - loss: 0.0483 - val_accuracy: 0.9733 - val_loss: 0.0608
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9835 - loss: 0.0454 - val_accuracy: 0.9727 - val_loss: 0.0606
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9836 - loss: 0.0435 - val_accuracy: 0.9733 - val_loss: 0.0587
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9830 - loss: 0.0460 - val_accuracy: 0.9739 - val_loss: 0.0608
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9838 - loss: 0.0456 - val_accuracy: 0.9733 - val_loss: 0.0636
# Epoch 31/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9833 - loss: 0.0458 - val_accuracy: 0.9731 - val_loss: 0.0637
# Epoch 32/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9824 - loss: 0.0464 - val_accuracy: 0.9731 - val_loss: 0.0636
# Epoch 33/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9834 - loss: 0.0467 - val_accuracy: 0.9767 - val_loss: 0.0607
# Epoch 34/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9830 - loss: 0.0442 - val_accuracy: 0.9736 - val_loss: 0.0591
# Epoch 35/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9831 - loss: 0.0441 - val_accuracy: 0.9766 - val_loss: 0.0600
# Epoch 36/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9840 - loss: 0.0443 - val_accuracy: 0.9728 - val_loss: 0.0608
# Epoch 37/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9841 - loss: 0.0448 - val_accuracy: 0.9739 - val_loss: 0.0600
# Epoch 38/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9836 - loss: 0.0444 - val_accuracy: 0.9739 - val_loss: 0.0598
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# Metrics for fold 3:
# accuracy: 0.9814
# precision: 0.9916
# recall: 0.9704
# f1: 0.9809
# mcc: 0.9629
# auc: 0.9983
# fpr: 0.0080
# specificity: 0.9920
# lr_plus: 121.3701
# lr_minus: 0.0298
#
# Fold 4/10
# ==================================================
# Epoch 1/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9009 - loss: 0.2351 - val_accuracy: 0.9482 - val_loss: 0.1402
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9598 - loss: 0.1048 - val_accuracy: 0.9542 - val_loss: 0.1076
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9660 - loss: 0.0917 - val_accuracy: 0.9599 - val_loss: 0.0930
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9730 - loss: 0.0789 - val_accuracy: 0.9490 - val_loss: 0.1017
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9730 - loss: 0.0742 - val_accuracy: 0.9682 - val_loss: 0.0806
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9757 - loss: 0.0707 - val_accuracy: 0.9665 - val_loss: 0.0830
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9751 - loss: 0.0703 - val_accuracy: 0.9614 - val_loss: 0.0757
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9769 - loss: 0.0649 - val_accuracy: 0.9601 - val_loss: 0.0810
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9785 - loss: 0.0639 - val_accuracy: 0.9620 - val_loss: 0.0697
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9792 - loss: 0.0618 - val_accuracy: 0.9625 - val_loss: 0.0720
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9799 - loss: 0.0591 - val_accuracy: 0.9620 - val_loss: 0.0714
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9801 - loss: 0.0595 - val_accuracy: 0.9611 - val_loss: 0.0657
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9808 - loss: 0.0561 - val_accuracy: 0.9623 - val_loss: 0.0614
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9798 - loss: 0.0568 - val_accuracy: 0.9704 - val_loss: 0.0654
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9801 - loss: 0.0536 - val_accuracy: 0.9631 - val_loss: 0.0644
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9812 - loss: 0.0554 - val_accuracy: 0.9725 - val_loss: 0.0615
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9811 - loss: 0.0531 - val_accuracy: 0.9632 - val_loss: 0.0634
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9815 - loss: 0.0515 - val_accuracy: 0.9631 - val_loss: 0.0643
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9814 - loss: 0.0537 - val_accuracy: 0.9635 - val_loss: 0.0635
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9812 - loss: 0.0521 - val_accuracy: 0.9629 - val_loss: 0.0632
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9810 - loss: 0.0544 - val_accuracy: 0.9634 - val_loss: 0.0629
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9826 - loss: 0.0517 - val_accuracy: 0.9631 - val_loss: 0.0637
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9816 - loss: 0.0513 - val_accuracy: 0.9619 - val_loss: 0.0624
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9821 - loss: 0.0507 - val_accuracy: 0.9635 - val_loss: 0.0640
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9814 - loss: 0.0548 - val_accuracy: 0.9634 - val_loss: 0.0604
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9821 - loss: 0.0519 - val_accuracy: 0.9638 - val_loss: 0.0564
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9807 - loss: 0.0509 - val_accuracy: 0.9631 - val_loss: 0.0646
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9825 - loss: 0.0520 - val_accuracy: 0.9634 - val_loss: 0.0621
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9817 - loss: 0.0513 - val_accuracy: 0.9637 - val_loss: 0.0577
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9827 - loss: 0.0507 - val_accuracy: 0.9620 - val_loss: 0.0631
# Epoch 31/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9832 - loss: 0.0503 - val_accuracy: 0.9635 - val_loss: 0.0605
# Epoch 32/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9826 - loss: 0.0506 - val_accuracy: 0.9727 - val_loss: 0.0592
# Epoch 33/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9822 - loss: 0.0503 - val_accuracy: 0.9637 - val_loss: 0.0597
# Epoch 34/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9819 - loss: 0.0500 - val_accuracy: 0.9638 - val_loss: 0.0616
# Epoch 35/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9828 - loss: 0.0522 - val_accuracy: 0.9635 - val_loss: 0.0601
# Epoch 36/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9822 - loss: 0.0504 - val_accuracy: 0.9620 - val_loss: 0.0668
# Epoch 37/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9821 - loss: 0.0499 - val_accuracy: 0.9632 - val_loss: 0.0636
# Epoch 38/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9822 - loss: 0.0515 - val_accuracy: 0.9733 - val_loss: 0.0618
# Epoch 39/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9833 - loss: 0.0463 - val_accuracy: 0.9632 - val_loss: 0.0620
# Epoch 40/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9821 - loss: 0.0499 - val_accuracy: 0.9634 - val_loss: 0.0638
# Epoch 41/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9824 - loss: 0.0477 - val_accuracy: 0.9634 - val_loss: 0.0608
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Metrics for fold 4:
# accuracy: 0.9781
# precision: 0.9983
# recall: 0.9586
# f1: 0.9781
# mcc: 0.9571
# auc: 0.9984
# fpr: 0.0016
# specificity: 0.9984
# lr_plus: 581.5366
# lr_minus: 0.0415
#
# Fold 5/10
# ==================================================
# Epoch 1/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9127 - loss: 0.2256 - val_accuracy: 0.9536 - val_loss: 0.1315
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9645 - loss: 0.0949 - val_accuracy: 0.9658 - val_loss: 0.1021
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9716 - loss: 0.0778 - val_accuracy: 0.9667 - val_loss: 0.0943
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9741 - loss: 0.0693 - val_accuracy: 0.9539 - val_loss: 0.0937
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9752 - loss: 0.0682 - val_accuracy: 0.9587 - val_loss: 0.0826
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9780 - loss: 0.0652 - val_accuracy: 0.9691 - val_loss: 0.0816
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9794 - loss: 0.0582 - val_accuracy: 0.9676 - val_loss: 0.0807
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9799 - loss: 0.0593 - val_accuracy: 0.9593 - val_loss: 0.0831
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9800 - loss: 0.0541 - val_accuracy: 0.9701 - val_loss: 0.0733
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9815 - loss: 0.0536 - val_accuracy: 0.9709 - val_loss: 0.0667
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9812 - loss: 0.0545 - val_accuracy: 0.9592 - val_loss: 0.0738
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9827 - loss: 0.0515 - val_accuracy: 0.9709 - val_loss: 0.0706
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9819 - loss: 0.0506 - val_accuracy: 0.9614 - val_loss: 0.0711
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9826 - loss: 0.0513 - val_accuracy: 0.9713 - val_loss: 0.0688
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9822 - loss: 0.0491 - val_accuracy: 0.9751 - val_loss: 0.0637
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9833 - loss: 0.0493 - val_accuracy: 0.9719 - val_loss: 0.0692
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9819 - loss: 0.0486 - val_accuracy: 0.9719 - val_loss: 0.0729
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9825 - loss: 0.0497 - val_accuracy: 0.9623 - val_loss: 0.0690
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9840 - loss: 0.0462 - val_accuracy: 0.9623 - val_loss: 0.0724
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9834 - loss: 0.0467 - val_accuracy: 0.9721 - val_loss: 0.0679
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9833 - loss: 0.0464 - val_accuracy: 0.9719 - val_loss: 0.0657
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9835 - loss: 0.0483 - val_accuracy: 0.9721 - val_loss: 0.0648
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9827 - loss: 0.0464 - val_accuracy: 0.9716 - val_loss: 0.0725
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9843 - loss: 0.0451 - val_accuracy: 0.9718 - val_loss: 0.0667
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9835 - loss: 0.0443 - val_accuracy: 0.9628 - val_loss: 0.0649
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9820 - loss: 0.0468 - val_accuracy: 0.9721 - val_loss: 0.0662
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9831 - loss: 0.0470 - val_accuracy: 0.9725 - val_loss: 0.0651
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9837 - loss: 0.0451 - val_accuracy: 0.9718 - val_loss: 0.0675
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9835 - loss: 0.0447 - val_accuracy: 0.9719 - val_loss: 0.0686
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9842 - loss: 0.0436 - val_accuracy: 0.9719 - val_loss: 0.0647
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Metrics for fold 5:
# accuracy: 0.9841
# precision: 0.9914
# recall: 0.9773
# f1: 0.9843
# mcc: 0.9682
# auc: 0.9984
# fpr: 0.0088
# specificity: 0.9912
# lr_plus: 110.5553
# lr_minus: 0.0229
#
# Fold 6/10
# ==================================================
# Epoch 1/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9065 - loss: 0.2291 - val_accuracy: 0.9595 - val_loss: 0.1185
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9613 - loss: 0.0977 - val_accuracy: 0.9622 - val_loss: 0.1086
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9689 - loss: 0.0842 - val_accuracy: 0.9622 - val_loss: 0.0984
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9714 - loss: 0.0726 - val_accuracy: 0.9580 - val_loss: 0.0922
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9736 - loss: 0.0689 - val_accuracy: 0.9671 - val_loss: 0.0846
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9767 - loss: 0.0656 - val_accuracy: 0.9557 - val_loss: 0.0889
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9774 - loss: 0.0624 - val_accuracy: 0.9725 - val_loss: 0.0684
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9776 - loss: 0.0602 - val_accuracy: 0.9691 - val_loss: 0.0748
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9798 - loss: 0.0569 - val_accuracy: 0.9649 - val_loss: 0.0719
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9804 - loss: 0.0571 - val_accuracy: 0.9613 - val_loss: 0.0701
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9799 - loss: 0.0552 - val_accuracy: 0.9635 - val_loss: 0.0699
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9809 - loss: 0.0543 - val_accuracy: 0.9613 - val_loss: 0.0727
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9807 - loss: 0.0549 - val_accuracy: 0.9614 - val_loss: 0.0752
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9819 - loss: 0.0527 - val_accuracy: 0.9712 - val_loss: 0.0654
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9804 - loss: 0.0537 - val_accuracy: 0.9713 - val_loss: 0.0649
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9822 - loss: 0.0508 - val_accuracy: 0.9614 - val_loss: 0.0710
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9824 - loss: 0.0504 - val_accuracy: 0.9619 - val_loss: 0.0667
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9816 - loss: 0.0529 - val_accuracy: 0.9721 - val_loss: 0.0602
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9825 - loss: 0.0508 - val_accuracy: 0.9716 - val_loss: 0.0643
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9824 - loss: 0.0506 - val_accuracy: 0.9719 - val_loss: 0.0633
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9823 - loss: 0.0508 - val_accuracy: 0.9722 - val_loss: 0.0604
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9831 - loss: 0.0485 - val_accuracy: 0.9722 - val_loss: 0.0638
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9819 - loss: 0.0478 - val_accuracy: 0.9724 - val_loss: 0.0578
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9821 - loss: 0.0492 - val_accuracy: 0.9724 - val_loss: 0.0594
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9827 - loss: 0.0484 - val_accuracy: 0.9721 - val_loss: 0.0630
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9825 - loss: 0.0486 - val_accuracy: 0.9719 - val_loss: 0.0629
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9826 - loss: 0.0489 - val_accuracy: 0.9722 - val_loss: 0.0610
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9836 - loss: 0.0483 - val_accuracy: 0.9725 - val_loss: 0.0586
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9834 - loss: 0.0472 - val_accuracy: 0.9722 - val_loss: 0.0597
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9831 - loss: 0.0467 - val_accuracy: 0.9721 - val_loss: 0.0648
# Epoch 31/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9826 - loss: 0.0483 - val_accuracy: 0.9719 - val_loss: 0.0651
# Epoch 32/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9830 - loss: 0.0466 - val_accuracy: 0.9724 - val_loss: 0.0616
# Epoch 33/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9829 - loss: 0.0476 - val_accuracy: 0.9721 - val_loss: 0.0616
# Epoch 34/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9821 - loss: 0.0477 - val_accuracy: 0.9727 - val_loss: 0.0580
# Epoch 35/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9830 - loss: 0.0474 - val_accuracy: 0.9727 - val_loss: 0.0583
# Epoch 36/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9830 - loss: 0.0458 - val_accuracy: 0.9724 - val_loss: 0.0612
# Epoch 37/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9830 - loss: 0.0488 - val_accuracy: 0.9727 - val_loss: 0.0615
# Epoch 38/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9833 - loss: 0.0457 - val_accuracy: 0.9725 - val_loss: 0.0581
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# Metrics for fold 6:
# accuracy: 0.9816
# precision: 0.9928
# recall: 0.9702
# f1: 0.9813
# mcc: 0.9635
# auc: 0.9981
# fpr: 0.0070
# specificity: 0.9930
# lr_plus: 138.8071
# lr_minus: 0.0301
#
# Fold 7/10
# ==================================================
# Epoch 1/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9030 - loss: 0.2340 - val_accuracy: 0.9673 - val_loss: 0.0965
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9619 - loss: 0.0965 - val_accuracy: 0.9670 - val_loss: 0.0879
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9687 - loss: 0.0845 - val_accuracy: 0.9713 - val_loss: 0.0776
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9737 - loss: 0.0729 - val_accuracy: 0.9676 - val_loss: 0.0755
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9749 - loss: 0.0711 - val_accuracy: 0.9701 - val_loss: 0.0741
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9771 - loss: 0.0656 - val_accuracy: 0.9728 - val_loss: 0.0672
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9773 - loss: 0.0641 - val_accuracy: 0.9719 - val_loss: 0.0676
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9775 - loss: 0.0625 - val_accuracy: 0.9619 - val_loss: 0.0787
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9802 - loss: 0.0564 - val_accuracy: 0.9803 - val_loss: 0.0590
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9798 - loss: 0.0565 - val_accuracy: 0.9772 - val_loss: 0.0587
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9808 - loss: 0.0540 - val_accuracy: 0.9725 - val_loss: 0.0613
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9799 - loss: 0.0538 - val_accuracy: 0.9745 - val_loss: 0.0577
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9828 - loss: 0.0522 - val_accuracy: 0.9728 - val_loss: 0.0652
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9824 - loss: 0.0504 - val_accuracy: 0.9746 - val_loss: 0.0581
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9815 - loss: 0.0524 - val_accuracy: 0.9737 - val_loss: 0.0568
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9827 - loss: 0.0521 - val_accuracy: 0.9734 - val_loss: 0.0606
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9829 - loss: 0.0512 - val_accuracy: 0.9736 - val_loss: 0.0600
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9815 - loss: 0.0538 - val_accuracy: 0.9730 - val_loss: 0.0647
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9829 - loss: 0.0492 - val_accuracy: 0.9730 - val_loss: 0.0573
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9826 - loss: 0.0501 - val_accuracy: 0.9734 - val_loss: 0.0583
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9827 - loss: 0.0504 - val_accuracy: 0.9725 - val_loss: 0.0608
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9825 - loss: 0.0504 - val_accuracy: 0.9641 - val_loss: 0.0604
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9823 - loss: 0.0493 - val_accuracy: 0.9640 - val_loss: 0.0645
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9828 - loss: 0.0486 - val_accuracy: 0.9733 - val_loss: 0.0569
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9828 - loss: 0.0489 - val_accuracy: 0.9733 - val_loss: 0.0620
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9823 - loss: 0.0492 - val_accuracy: 0.9643 - val_loss: 0.0617
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9840 - loss: 0.0472 - val_accuracy: 0.9737 - val_loss: 0.0575
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9826 - loss: 0.0484 - val_accuracy: 0.9644 - val_loss: 0.0604
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9832 - loss: 0.0476 - val_accuracy: 0.9737 - val_loss: 0.0585
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9832 - loss: 0.0472 - val_accuracy: 0.9731 - val_loss: 0.0599
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Metrics for fold 7:
# accuracy: 0.9833
# precision: 0.9921
# recall: 0.9735
# f1: 0.9827
# mcc: 0.9666
# auc: 0.9988
# fpr: 0.0074
# specificity: 0.9926
# lr_plus: 131.7636
# lr_minus: 0.0267
#
# Fold 8/10
# ==================================================
# Epoch 1/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9084 - loss: 0.2273 - val_accuracy: 0.9611 - val_loss: 0.1100
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9599 - loss: 0.1014 - val_accuracy: 0.9634 - val_loss: 0.1100
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9694 - loss: 0.0845 - val_accuracy: 0.9610 - val_loss: 0.0945
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9715 - loss: 0.0760 - val_accuracy: 0.9616 - val_loss: 0.0941
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9756 - loss: 0.0693 - val_accuracy: 0.9649 - val_loss: 0.0882
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9767 - loss: 0.0652 - val_accuracy: 0.9656 - val_loss: 0.0845
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9784 - loss: 0.0611 - val_accuracy: 0.9665 - val_loss: 0.0845
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9790 - loss: 0.0604 - val_accuracy: 0.9682 - val_loss: 0.0796
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9801 - loss: 0.0588 - val_accuracy: 0.9667 - val_loss: 0.0880
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9798 - loss: 0.0565 - val_accuracy: 0.9700 - val_loss: 0.0734
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9803 - loss: 0.0582 - val_accuracy: 0.9704 - val_loss: 0.0778
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9800 - loss: 0.0546 - val_accuracy: 0.9709 - val_loss: 0.0759
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9816 - loss: 0.0526 - val_accuracy: 0.9709 - val_loss: 0.0704
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9814 - loss: 0.0529 - val_accuracy: 0.9707 - val_loss: 0.0725
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9813 - loss: 0.0511 - val_accuracy: 0.9709 - val_loss: 0.0737
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9813 - loss: 0.0522 - val_accuracy: 0.9701 - val_loss: 0.0667
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9820 - loss: 0.0495 - val_accuracy: 0.9706 - val_loss: 0.0729
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9817 - loss: 0.0482 - val_accuracy: 0.9707 - val_loss: 0.0673
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9816 - loss: 0.0509 - val_accuracy: 0.9707 - val_loss: 0.0687
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9815 - loss: 0.0495 - val_accuracy: 0.9707 - val_loss: 0.0651
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9812 - loss: 0.0538 - val_accuracy: 0.9709 - val_loss: 0.0669
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9811 - loss: 0.0505 - val_accuracy: 0.9707 - val_loss: 0.0687
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9820 - loss: 0.0489 - val_accuracy: 0.9698 - val_loss: 0.0736
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9825 - loss: 0.0473 - val_accuracy: 0.9709 - val_loss: 0.0629
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9823 - loss: 0.0489 - val_accuracy: 0.9709 - val_loss: 0.0629
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9824 - loss: 0.0481 - val_accuracy: 0.9709 - val_loss: 0.0699
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9815 - loss: 0.0485 - val_accuracy: 0.9721 - val_loss: 0.0654
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9819 - loss: 0.0480 - val_accuracy: 0.9715 - val_loss: 0.0698
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9822 - loss: 0.0469 - val_accuracy: 0.9697 - val_loss: 0.0740
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9824 - loss: 0.0495 - val_accuracy: 0.9712 - val_loss: 0.0661
# Epoch 31/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9821 - loss: 0.0474 - val_accuracy: 0.9719 - val_loss: 0.0659
# Epoch 32/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9820 - loss: 0.0471 - val_accuracy: 0.9719 - val_loss: 0.0669
# Epoch 33/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9819 - loss: 0.0468 - val_accuracy: 0.9709 - val_loss: 0.0672
# Epoch 34/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9818 - loss: 0.0481 - val_accuracy: 0.9719 - val_loss: 0.0646
# Epoch 35/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9832 - loss: 0.0459 - val_accuracy: 0.9719 - val_loss: 0.0626
# Epoch 36/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9834 - loss: 0.0467 - val_accuracy: 0.9704 - val_loss: 0.0644
# Epoch 37/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9820 - loss: 0.0475 - val_accuracy: 0.9716 - val_loss: 0.0610
# Epoch 38/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9831 - loss: 0.0476 - val_accuracy: 0.9716 - val_loss: 0.0653
# Epoch 39/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9829 - loss: 0.0475 - val_accuracy: 0.9710 - val_loss: 0.0639
# Epoch 40/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9830 - loss: 0.0458 - val_accuracy: 0.9719 - val_loss: 0.0638
# Epoch 41/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9825 - loss: 0.0463 - val_accuracy: 0.9707 - val_loss: 0.0625
# Epoch 42/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9822 - loss: 0.0456 - val_accuracy: 0.9718 - val_loss: 0.0602
# Epoch 43/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9822 - loss: 0.0460 - val_accuracy: 0.9721 - val_loss: 0.0614
# Epoch 44/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9827 - loss: 0.0469 - val_accuracy: 0.9721 - val_loss: 0.0648
# Epoch 45/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9833 - loss: 0.0471 - val_accuracy: 0.9719 - val_loss: 0.0624
# Epoch 46/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9828 - loss: 0.0471 - val_accuracy: 0.9719 - val_loss: 0.0606
# Epoch 47/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9828 - loss: 0.0457 - val_accuracy: 0.9712 - val_loss: 0.0666
# Epoch 48/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9829 - loss: 0.0449 - val_accuracy: 0.9716 - val_loss: 0.0602
# Epoch 49/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9826 - loss: 0.0460 - val_accuracy: 0.9721 - val_loss: 0.0573
# Epoch 50/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9827 - loss: 0.0454 - val_accuracy: 0.9713 - val_loss: 0.0640
# Epoch 51/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9834 - loss: 0.0447 - val_accuracy: 0.9718 - val_loss: 0.0628
# Epoch 52/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9834 - loss: 0.0450 - val_accuracy: 0.9716 - val_loss: 0.0635
# Epoch 53/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9835 - loss: 0.0457 - val_accuracy: 0.9716 - val_loss: 0.0630
# Epoch 54/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9832 - loss: 0.0461 - val_accuracy: 0.9715 - val_loss: 0.0634
# Epoch 55/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9822 - loss: 0.0480 - val_accuracy: 0.9715 - val_loss: 0.0635
# Epoch 56/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9836 - loss: 0.0446 - val_accuracy: 0.9719 - val_loss: 0.0634
# Epoch 57/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9828 - loss: 0.0467 - val_accuracy: 0.9719 - val_loss: 0.0631
# Epoch 58/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9831 - loss: 0.0449 - val_accuracy: 0.9721 - val_loss: 0.0631
# Epoch 59/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9829 - loss: 0.0450 - val_accuracy: 0.9719 - val_loss: 0.0586
# Epoch 60/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9831 - loss: 0.0456 - val_accuracy: 0.9719 - val_loss: 0.0633
# Epoch 61/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9839 - loss: 0.0428 - val_accuracy: 0.9718 - val_loss: 0.0613
# Epoch 62/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9835 - loss: 0.0435 - val_accuracy: 0.9721 - val_loss: 0.0600
# Epoch 63/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9831 - loss: 0.0447 - val_accuracy: 0.9718 - val_loss: 0.0646
# Epoch 64/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9829 - loss: 0.0455 - val_accuracy: 0.9721 - val_loss: 0.0613
# Epoch 64: early stopping
# Restoring model weights from the end of the best epoch: 49.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Metrics for fold 8:
# accuracy: 0.9857
# precision: 0.9946
# recall: 0.9772
# f1: 0.9858
# mcc: 0.9715
# auc: 0.9988
# fpr: 0.0055
# specificity: 0.9945
# lr_plus: 177.3663
# lr_minus: 0.0229
#
# Fold 9/10
# ==================================================
# Epoch 1/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9034 - loss: 0.2285 - val_accuracy: 0.9563 - val_loss: 0.1107
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9644 - loss: 0.0990 - val_accuracy: 0.9652 - val_loss: 0.0880
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9704 - loss: 0.0832 - val_accuracy: 0.9667 - val_loss: 0.0913
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9717 - loss: 0.0767 - val_accuracy: 0.9671 - val_loss: 0.0917
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9751 - loss: 0.0691 - val_accuracy: 0.9704 - val_loss: 0.0792
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9768 - loss: 0.0658 - val_accuracy: 0.9575 - val_loss: 0.0823
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9780 - loss: 0.0644 - val_accuracy: 0.9709 - val_loss: 0.0728
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9792 - loss: 0.0615 - val_accuracy: 0.9754 - val_loss: 0.0664
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9808 - loss: 0.0559 - val_accuracy: 0.9652 - val_loss: 0.0631
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9805 - loss: 0.0558 - val_accuracy: 0.9722 - val_loss: 0.0596
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9818 - loss: 0.0562 - val_accuracy: 0.9725 - val_loss: 0.0627
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9811 - loss: 0.0544 - val_accuracy: 0.9730 - val_loss: 0.0656
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9815 - loss: 0.0520 - val_accuracy: 0.9635 - val_loss: 0.0616
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9812 - loss: 0.0530 - val_accuracy: 0.9733 - val_loss: 0.0594
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9827 - loss: 0.0510 - val_accuracy: 0.9641 - val_loss: 0.0622
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9829 - loss: 0.0511 - val_accuracy: 0.9739 - val_loss: 0.0623
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9828 - loss: 0.0497 - val_accuracy: 0.9733 - val_loss: 0.0599
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9826 - loss: 0.0496 - val_accuracy: 0.9643 - val_loss: 0.0585
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9828 - loss: 0.0488 - val_accuracy: 0.9641 - val_loss: 0.0589
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9825 - loss: 0.0489 - val_accuracy: 0.9739 - val_loss: 0.0545
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9828 - loss: 0.0488 - val_accuracy: 0.9745 - val_loss: 0.0555
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9838 - loss: 0.0471 - val_accuracy: 0.9649 - val_loss: 0.0576
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9823 - loss: 0.0474 - val_accuracy: 0.9740 - val_loss: 0.0562
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9833 - loss: 0.0495 - val_accuracy: 0.9746 - val_loss: 0.0529
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9836 - loss: 0.0463 - val_accuracy: 0.9740 - val_loss: 0.0577
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9844 - loss: 0.0474 - val_accuracy: 0.9740 - val_loss: 0.0563
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9837 - loss: 0.0472 - val_accuracy: 0.9743 - val_loss: 0.0583
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9833 - loss: 0.0458 - val_accuracy: 0.9740 - val_loss: 0.0561
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9839 - loss: 0.0473 - val_accuracy: 0.9739 - val_loss: 0.0534
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9833 - loss: 0.0472 - val_accuracy: 0.9733 - val_loss: 0.0567
# Epoch 31/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9839 - loss: 0.0468 - val_accuracy: 0.9742 - val_loss: 0.0519
# Epoch 32/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9823 - loss: 0.0475 - val_accuracy: 0.9739 - val_loss: 0.0593
# Epoch 33/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9840 - loss: 0.0460 - val_accuracy: 0.9733 - val_loss: 0.0565
# Epoch 34/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9840 - loss: 0.0464 - val_accuracy: 0.9743 - val_loss: 0.0569
# Epoch 35/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9852 - loss: 0.0443 - val_accuracy: 0.9739 - val_loss: 0.0558
# Epoch 36/200
# ...
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9783 - loss: 0.0629 - val_accuracy: 0.9734 - val_loss: 0.0679
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9791 - loss: 0.0604 - val_accuracy: 0.9769 - val_loss: 0.0632
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9800 - loss: 0.0577 - val_accuracy: 0.9757 - val_loss: 0.0609
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9808 - loss: 0.0575 - val_accuracy: 0.9733 - val_loss: 0.0591
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9796 - loss: 0.0565 - val_accuracy: 0.9734 - val_loss: 0.0608
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9803 - loss: 0.0560 - val_accuracy: 0.9731 - val_loss: 0.0579
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9812 - loss: 0.0546 - val_accuracy: 0.9734 - val_loss: 0.0601
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9812 - loss: 0.0560 - val_accuracy: 0.9776 - val_loss: 0.0609
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9804 - loss: 0.0574 - val_accuracy: 0.9736 - val_loss: 0.0602
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9815 - loss: 0.0525 - val_accuracy: 0.9739 - val_loss: 0.0547
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9820 - loss: 0.0518 - val_accuracy: 0.9743 - val_loss: 0.0572
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9821 - loss: 0.0528 - val_accuracy: 0.9739 - val_loss: 0.0554
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9821 - loss: 0.0500 - val_accuracy: 0.9737 - val_loss: 0.0558
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9821 - loss: 0.0525 - val_accuracy: 0.9734 - val_loss: 0.0576
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9826 - loss: 0.0507 - val_accuracy: 0.9734 - val_loss: 0.0586
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9817 - loss: 0.0526 - val_accuracy: 0.9733 - val_loss: 0.0582
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9818 - loss: 0.0511 - val_accuracy: 0.9733 - val_loss: 0.0600
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9821 - loss: 0.0499 - val_accuracy: 0.9734 - val_loss: 0.0568
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9810 - loss: 0.0532 - val_accuracy: 0.9740 - val_loss: 0.0582
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9825 - loss: 0.0488 - val_accuracy: 0.9745 - val_loss: 0.0571
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9818 - loss: 0.0489 - val_accuracy: 0.9743 - val_loss: 0.0545
# Epoch 31/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9826 - loss: 0.0496 - val_accuracy: 0.9740 - val_loss: 0.0541
# Epoch 32/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0487 - val_accuracy: 0.9742 - val_loss: 0.0601
# Epoch 33/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9825 - loss: 0.0486 - val_accuracy: 0.9740 - val_loss: 0.0611
# Epoch 34/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9828 - loss: 0.0514 - val_accuracy: 0.9742 - val_loss: 0.0584
# Epoch 35/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9827 - loss: 0.0472 - val_accuracy: 0.9742 - val_loss: 0.0590
# Epoch 36/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9832 - loss: 0.0487 - val_accuracy: 0.9739 - val_loss: 0.0590
# Epoch 37/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0495 - val_accuracy: 0.9743 - val_loss: 0.0576
# Epoch 38/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9822 - loss: 0.0502 - val_accuracy: 0.9743 - val_loss: 0.0570
# Epoch 39/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9822 - loss: 0.0491 - val_accuracy: 0.9742 - val_loss: 0.0575
# Epoch 40/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9832 - loss: 0.0481 - val_accuracy: 0.9739 - val_loss: 0.0590
# Epoch 41/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9834 - loss: 0.0480 - val_accuracy: 0.9742 - val_loss: 0.0553
# Epoch 42/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9816 - loss: 0.0506 - val_accuracy: 0.9742 - val_loss: 0.0562
# Epoch 43/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9823 - loss: 0.0480 - val_accuracy: 0.9742 - val_loss: 0.0570
# Epoch 44/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9829 - loss: 0.0477 - val_accuracy: 0.9740 - val_loss: 0.0557
# Epoch 45/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9827 - loss: 0.0472 - val_accuracy: 0.9740 - val_loss: 0.0571
# Epoch 46/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9831 - loss: 0.0460 - val_accuracy: 0.9740 - val_loss: 0.0575
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 31.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Metrics for fold 10:
# accuracy: 0.9841
# precision: 0.9927
# recall: 0.9746
# f1: 0.9835
# mcc: 0.9682
# auc: 0.9989
# fpr: 0.0069
# specificity: 0.9931
# lr_plus: 141.9855
# lr_minus: 0.0256
#
# Training final model on entire dataset...
# Epoch 1/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9105 - loss: 0.2197 - val_accuracy: 0.9536 - val_loss: 0.1446
# Epoch 2/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9602 - loss: 0.1027 - val_accuracy: 0.9357 - val_loss: 0.1594
# Epoch 3/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9689 - loss: 0.0869 - val_accuracy: 0.9549 - val_loss: 0.1100
# Epoch 4/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9716 - loss: 0.0772 - val_accuracy: 0.9637 - val_loss: 0.0954
# Epoch 5/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9745 - loss: 0.0736 - val_accuracy: 0.9545 - val_loss: 0.0900
# Epoch 6/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9738 - loss: 0.0709 - val_accuracy: 0.9563 - val_loss: 0.0888
# Epoch 7/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9766 - loss: 0.0644 - val_accuracy: 0.9607 - val_loss: 0.0725
# Epoch 8/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9777 - loss: 0.0621 - val_accuracy: 0.9612 - val_loss: 0.0723
# Epoch 9/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9777 - loss: 0.0621 - val_accuracy: 0.9612 - val_loss: 0.0741
# Epoch 10/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9784 - loss: 0.0590 - val_accuracy: 0.9621 - val_loss: 0.0625
# Epoch 11/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9794 - loss: 0.0575 - val_accuracy: 0.9718 - val_loss: 0.0642
# Epoch 12/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9800 - loss: 0.0552 - val_accuracy: 0.9626 - val_loss: 0.0659
# Epoch 13/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9792 - loss: 0.0546 - val_accuracy: 0.9629 - val_loss: 0.0731
# Epoch 14/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9801 - loss: 0.0542 - val_accuracy: 0.9626 - val_loss: 0.0684
# Epoch 15/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9802 - loss: 0.0567 - val_accuracy: 0.9629 - val_loss: 0.0647
# Epoch 16/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9811 - loss: 0.0533 - val_accuracy: 0.9734 - val_loss: 0.0624
# Epoch 17/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9822 - loss: 0.0522 - val_accuracy: 0.9623 - val_loss: 0.0728
# Epoch 18/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9808 - loss: 0.0535 - val_accuracy: 0.9630 - val_loss: 0.0627
# Epoch 19/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9808 - loss: 0.0514 - val_accuracy: 0.9631 - val_loss: 0.0668
# Epoch 20/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9816 - loss: 0.0507 - val_accuracy: 0.9630 - val_loss: 0.0634
# Epoch 21/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0502 - val_accuracy: 0.9631 - val_loss: 0.0633
# Epoch 22/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9822 - loss: 0.0490 - val_accuracy: 0.9629 - val_loss: 0.0627
# Epoch 23/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9811 - loss: 0.0494 - val_accuracy: 0.9634 - val_loss: 0.0644
# Epoch 24/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9835 - loss: 0.0491 - val_accuracy: 0.9729 - val_loss: 0.0561
# Epoch 25/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9824 - loss: 0.0491 - val_accuracy: 0.9633 - val_loss: 0.0654
# Epoch 26/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9821 - loss: 0.0489 - val_accuracy: 0.9641 - val_loss: 0.0611
# Epoch 27/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9820 - loss: 0.0489 - val_accuracy: 0.9734 - val_loss: 0.0606
# Epoch 28/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9829 - loss: 0.0490 - val_accuracy: 0.9746 - val_loss: 0.0565
# Epoch 29/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9819 - loss: 0.0497 - val_accuracy: 0.9733 - val_loss: 0.0615
# Epoch 30/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9824 - loss: 0.0503 - val_accuracy: 0.9635 - val_loss: 0.0623
# Epoch 31/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9832 - loss: 0.0484 - val_accuracy: 0.9737 - val_loss: 0.0604
# Epoch 32/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9824 - loss: 0.0486 - val_accuracy: 0.9735 - val_loss: 0.0582
# Epoch 33/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9826 - loss: 0.0471 - val_accuracy: 0.9639 - val_loss: 0.0601
# Epoch 34/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9828 - loss: 0.0470 - val_accuracy: 0.9734 - val_loss: 0.0593
# Epoch 35/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9827 - loss: 0.0490 - val_accuracy: 0.9737 - val_loss: 0.0556
# Epoch 36/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9830 - loss: 0.0488 - val_accuracy: 0.9635 - val_loss: 0.0627
# Epoch 37/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0485 - val_accuracy: 0.9731 - val_loss: 0.0615
# Epoch 38/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9834 - loss: 0.0481 - val_accuracy: 0.9737 - val_loss: 0.0597
# Epoch 39/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9832 - loss: 0.0477 - val_accuracy: 0.9638 - val_loss: 0.0626
# Epoch 40/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9827 - loss: 0.0481 - val_accuracy: 0.9641 - val_loss: 0.0596
# Epoch 41/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9818 - loss: 0.0466 - val_accuracy: 0.9633 - val_loss: 0.0627
# Epoch 42/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9816 - loss: 0.0489 - val_accuracy: 0.9641 - val_loss: 0.0627
# Epoch 43/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0479 - val_accuracy: 0.9642 - val_loss: 0.0594
# Epoch 44/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9821 - loss: 0.0460 - val_accuracy: 0.9738 - val_loss: 0.0599
# Epoch 45/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9830 - loss: 0.0460 - val_accuracy: 0.9737 - val_loss: 0.0555
# Epoch 46/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9826 - loss: 0.0452 - val_accuracy: 0.9641 - val_loss: 0.0624
# Epoch 47/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9819 - loss: 0.0476 - val_accuracy: 0.9737 - val_loss: 0.0595
# Epoch 48/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9832 - loss: 0.0475 - val_accuracy: 0.9737 - val_loss: 0.0598
# Epoch 49/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9836 - loss: 0.0449 - val_accuracy: 0.9738 - val_loss: 0.0593
# Epoch 50/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9826 - loss: 0.0460 - val_accuracy: 0.9737 - val_loss: 0.0585
# Epoch 51/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9828 - loss: 0.0472 - val_accuracy: 0.9652 - val_loss: 0.0615
# Epoch 52/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9824 - loss: 0.0471 - val_accuracy: 0.9639 - val_loss: 0.0632
# Epoch 53/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9830 - loss: 0.0447 - val_accuracy: 0.9637 - val_loss: 0.0594
# Epoch 54/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9827 - loss: 0.0458 - val_accuracy: 0.9641 - val_loss: 0.0589
# Epoch 55/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9835 - loss: 0.0472 - val_accuracy: 0.9734 - val_loss: 0.0593
# Epoch 56/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9825 - loss: 0.0478 - val_accuracy: 0.9735 - val_loss: 0.0576
# Epoch 57/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9834 - loss: 0.0457 - val_accuracy: 0.9644 - val_loss: 0.0593
# Epoch 58/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9824 - loss: 0.0475 - val_accuracy: 0.9642 - val_loss: 0.0592
# Epoch 59/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9830 - loss: 0.0456 - val_accuracy: 0.9737 - val_loss: 0.0592
# Epoch 60/200
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9831 - loss: 0.0459 - val_accuracy: 0.9738 - val_loss: 0.0566
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 45.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Final model saved to covid_ann_results\final_model.h5
#
# ==================================================
# FINAL SUMMARY
# ==================================================
#
# Model Architecture:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_10 (Flatten)                 │ (None, 10)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_40 (Dense)                     │ (None, 128)                 │           1,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_30 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_41 (Dense)                     │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_31 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_42 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_32 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_43 (Dense)                     │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 202,373 (790.52 KB)
#  Trainable params: 67,457 (263.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 134,916 (527.02 KB)
# Industry-Standard Parameters Used:
# - Dropout rates: 0.3 (first layer), 0.5 (deeper layers)
# - Learning rate: 0.001
# - Batch size: 64
# - Network architecture: 128-256-128-1 neurons
# - Early stopping patience: 15 epochs
# - Max epochs: 200
#
# Average metrics across all folds:
# accuracy: 0.9815 ± 0.0029
# precision: 0.9923 ± 0.0036
# recall: 0.9705 ± 0.0056
# f1: 0.9813 ± 0.0030
# mcc: 0.9632 ± 0.0056
# auc: 0.9985 ± 0.0003
# fpr: 0.0075 ± 0.0034
# specificity: 0.9925 ± 0.0034
# lr_plus: 177.8120 ± 148.1546
# lr_minus: 0.0297 ± 0.0056
#
# All results and model saved to: covid_ann_results
#
# Full path to output directory: C:\Users\aurok\covid_ann_results
